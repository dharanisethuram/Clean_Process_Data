# %%
pwd
# Out:
# '/Users/dharanisethuram/SamplePro'

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('cleanUser_Ment.csv')
# This data haa no NaN values of mentions

# %%
# Username's are put into a list!
du = df['Username']
#du = du[0:10000]
arr = [100] #adjust to needed 
uname = []
for row in du:
    uname.append(row)
print (uname)
# Out:
# ['C_lorennxx', 'JACK_in_ur_box', 'torilussier', 'gabbbiee', 'AyoooooMont', 'laurencasale_', 'sammie_ce', 'orbiqa', 'GCoss5', 'Asap_Mamba_', 'nirhalegi', 'kathrynminer15', 'johnwehler', 'ItchinForPaper', 'one_spicy_nacho', 'skinsken', '__Moochieee', 'jonvox', 'neilvogel', 'christiannnh', 'StopTwatchin215', 'robgchill', 'Corey12551', 'SanabriaLizbeth', 'SeanTaylorNice', 'Young_Boss501', 'davehalikman', 'kristaa424', 'vargasteph', 'sports_247365', 'Liz_Quintela', 'CaseyCoudrey', 'cory1976', 'nataliegallops', 'alexaacho', 'BigHerk106', 'CorrineVicari', 'KelseyForgione', 'ADuff36', 'Holmes855', 'Big_Burnsy12', 'therealDSnydes', 'markie_vega', '_corinnepatt', 'BangsWitMe', 'kelseamorgann', 'WhoGabe', 'alecperkins', 'xKeylaDuarte', 'NotPreston', 'jcbivins', 'R3daBook', 'cyyann_', 'BlackxxDynamite', 'safroota', 'RaechelMorgan', 'AARONSTIXSMITH', 'BDesaulnier34', 'ReggieDaSecond', 'mike_bojko', 'CORINNEGABPATTI', 'becca_buenoo', 'xStinkfacex', '_mirandalynch_', 'alanalindsayz', 'Rason_WhoBetta', 'k_vaughnn', 'TeamSeXysCrisA', 'ChewConnor', 'jascarro', 'Basil_foreal', 'Kwame_Banks', 'MorganSup', 'WorcesterBarFx', 'Jay_Higgs11', 'RCabrey', 'PiiNK_Dollaz', 'Erikawiz', 'MollyWakefield', 'jackiegheraldi', 'killernj13', 'stevencollen98', 'scbylove11', 'jenngoldstone', 'Gabriella4pabst', 'Herrera_Al01', 'JohnJLilley', 'StayyCheeeesinn', 'CanCanMarie', 'joefitz_', 'guan', 'I_AM_shortness', 'HandyAndy93', 'S_j_L2', 'iamjimmyvargass', 'paulmedeiros3', 'StefanMoore12', 'Csheehan369', 'IamTayyTayy', 'daisyydott', 'trivedi_nitish', 'emmbarbieri', 'itssilly_lil_me', 'jayfelic5', 'kcastrox3', 'adaytosurvive', 'FuckN0rmality', 'Amaris_Acosta', 'Natii_Says', 'rumor2u', 'breehee_vazquez', 'XMalibu69X', 'georg_marie', 'LittleBit_Ann', 'j_ericadeforge', 'Sheria1', 'Jersquall', 'iasbelys', 'juniormv316', 'StepOnThe_MATT', 'kalinpriest', 'beeswrite', 'BruceJVail', 'jaysteph89', 'a_marie__', 'Sexy_Latin_Marc', 'NICKaPHENOM', 'itsamisaad', 'HOlliCrombiie', 'Str8t_CashX3', 'Starthe_ItGirl', 'BillyHoward423', 'YeathatsKiana_', 'Tj_TheSpark', 'dchamp89', 'massrealty', 'allis0n8', 'Liyah_IsTruth', 'allybmartin', 'SWAHL_sack', 'SupaJuanitO', 'AveryLeon2', 'arianabiagioni', 'msliljones9771', 'RealXavierRoden', 'kalliecif', 'lilwill_ashley', 'skenigsberg', 'maannddaa17', 'thejudgeryan', 'totti_bsc', 'tacoteej', 'MuchiexO', 'MCorreia12', 'fgbm27', 'sheepthechicken', 'hardtohandlexv', 'nsxentr', 'britty_mariee', 'Edwins_ghost502', 'ElizabethSReis', 'Diego_Cardona95', 'I_AM_shortness', 'Chlastawa', 'Adrians_Story', 'itzchandnixo', 'donde58', 'lisabeth1069', 'cheyennewaterss', '_Black_Hat_', 'KieranScott', 'ayoCHIII', 'tinakayxoxo', 'JohnBon345', 'Num1HandsomeBoy', 'Uantboutthtlyf', 'adeline_green', 'ekworrall', 'TannerBegg', 'patrickbacolod', 'MsCarter69Roc', 'McPhridric', 'M_BoRcH3', 'lloyd_says', 'mattiswack13', 'RepDat617_BSM', 'clone00', 'BradenKoch', 'LauraGosneyy', 'earthtopatricia', 'TuncAyQuliyev', 'selenanatale', 'JuAlreadyKnow', 'RobynForest', '_Savonna_Nicole', 'amykstudio', 'jackiegheraldi', 'Taalllllent', 'ceddyrock23', 'jonnyrockett_', 'Dj_Cruiiser', 'makennalp', 'cleevycleeve', 'amazon_v', 'meriSsy_joy', 'youalreadyknowT', 'TheRealEhqo', 'LindsayMotta24', 'joeCARTOONguy', 'cassiex0ellis', 'palakypoo', 'oliethagoalie', 'BLockwood12', 'santiagosanch98', '_MoNique_Jayy', 'L0veSyl', 'CXCart', 'DillonHotwhlz88', 'ambiousdes_xo', 'crecre1', 'Jayp_Bang', 'jayfrench_x3', 'popudig', 'SheSayNoZayStay', 'chrisg_2196', '_ZacDick', 'Y0GabbbaGabbba', 'Disney_Deb', 'HelloJen5150', 'dmangilomini', 'Follow_my_path', 'ObeyKaylaa', 'Buttazzzz_99', 'd_donahuee', 'Tneebre', 'reillycook', 'hailslombardii', 'Gregggyboy', 'Hard23_head', 'VinnyLatorraca', 'AnnieIntili', 'ManhattanzElite', 'AJ_Bernabe', 'SarahOlkkola', 'Jarred_Diorio', 'Mika_Augustin', 'The_Ambition_', 'f1y_FAR_away', 'kate_larochelle', 'M_MILLS4', 'Kelimaggie', 'BGault88', 'joemasilotti', 'Cwalks3', 'MattHurst', 'ArtsyDenzzy', 'AutumnAllenn', 'sophiadeleonxo', 'KelseyAnnKeough', 'emilsis', 'mcgrath_alyssa', 'iFn ...

# %%
dm = df['Mentions']

#print(m)
#arr[100]
x = []
for row in dm:
   x.append(row)
print(x)
# Out:
# ['Live_Strong_30, ', 'wrath_of_rathje, TUCK_U_2_SLEEP, ', 'nclemens_02, OhMyDarling118, ', 'nicki3diesel, ', 'KendrickLaamar, JColeNC, ', 'JessicaNieberg1, ', 'GodPosts, ', 'Lukaymusic, ', 'DJ_RJCoia, Chris_Lansdown, ', 'BWebb32, ', 'toritoosalzman, roseleemcrbarbo, melanisiwalton, rufinabsmyrick, ', 'tumblr, ', 'brynardone, ', 'bdeabreu27, nikiDxoxo, ', 'LaCreme_x, ', 'scottlinn980, ', 'bhritcv, ', 'chrsphr, ', 'MikeBloomberg, ', 'sarahlawton13, ', 'Sophia_Fury, ', 'Bakes_Jamie13, ', 'CarolineLFerrer, ', 'ItsNi_thoo, ', 'HardInTheYard, ', 'LiveLoveYoshi, ', 'domcarusone, ', 'kid_polansk, ', 'kenzwall, ', 'HBO, ', 'MattRevenir, ', 'ariianababiix, ', 'BostonBrodes, ', 'NYTMetro, ', 'Cpt_Inshane_O, ', 'steponme084, ', 'CrysB_999, PaigeVicari, ', 'emily_wood9, ', 'KelseyNiz, ', 'okwerdz, ', 'TylerGalligan, Gucci_Steve, ', 'Lord_Bobbymort, ', 'bethanyprezioso, ', 'OliviaTrainor, ', 'MaccSuave, ', 'kikilovescats, ', 'Larwar11, ', 'brianjschneider, ', 'xo_melaniex3, ', 'xANDRULFx, ', 'AshleyEngelman, ', 'Timmy_Kimmy, ', 'megan_nehiley, ', 'jocelynn__xoxo, ', 'settak_sandy, BiebsUAE, iRou2a, iSalmaSmiler, ', 'alyssa_borrelli, ', '_Mama_Cita_, ', 'bernicee16, ', 'Jenannnn, ', 'FarrisJamal, ', 'KatelynShamp, ', 'TessaAnzly, ', 'kennyMCfly, ', 'AleexHouviie, ', 'greatiscait, ', 'Starrkisses_, ', 'molinaro_p, ', 'EmilioBGE, ', 'Deannerrr, ', 'Mig_Lovin, ', 'devonedalovergi, ', 'Jamno233, ', 'mauraagz, CaitlynCopp08, ebon_yoyo, ', 'leyshh_3, ', 'im_the_TIN_mAn, ', 'devindakes, ', 'Avsp_TAC0, ', 'Sheikxlove, ', 'ajahnhuggins, ', 'RooneyMorris, ', 'realDonaldTrump, ', 'NiallOfficial, ', 'dan_ursino, lizzyjlucas, ', 'eh, ', 'mcuphoenix37, ', 'swag3katelyn, ', 'callmephil, ', 'Nataliee_Lynnx3, ', 'c_fabs, ', 'BigDaddyGraham, ', 'sabokitty, ', 'Free2Speak87, ', 'JTturban, ', 'RegularWalt, ', 'MarleRios, ', 'Griss_Martinez, ', 'ginaedicarlo, ', 'Dunn_Dylan23, erinrin_paige, JAD_023, ArianaGrande, justinbieber, ', 'Poooh_Beaar, ', 'gabefriedin, ', '8765432100000, ', 'kail204, ', 'Kingz_of_Eden, ', 'JeffDriscoll1, ', 'Valerio_Aldo, ', '_MandaxPanda, ', 'NoRegrets_16, ', 'svictoria24, ', 'MGBarbie, ', 'RICKTATORSHIP, glenmazzara, ', 'saraabootayy, ', 'GooseIsland, XMalibu69X, ', 'giibabii_17, ', 'NaatalieeG, ', 'biljacobson, ', 'cher, ', 'Terra_Cide, ', 'Camposssx3, ', 'calamariolives, ', 'CallMeDubstep, ', 'tommyklein_7, tori_smith8, ', 'ChronOfCashmere, unfoRETTAble, beeswrite, ', 'lisaaaharri94, ', 'LarryFitzgerald, ', 'MACproDetroit, ', 'AlexPonce_91, ', 'ali_turowsky, ', 'JonnySlice, ', 'iEstebann, ', 'AubreyMars_, ', 'RhymesUnwritten, ', 'cfgstw, ', '_NoStylinn, ', 'NicoleeShonte_, ', 'dfr3nch, dev_williamson, ', 'CantonMass, ', 'realDonaldTrump, dennisrodman, CelebApprentice, ', 'i_WhiteGirl, ', 'dempseytaylor, ', 'chris_ganley, mike_crousee, biehl_, ', 'GovChristie, ', 'MacySullivan4, ', 'victoriasidotii, ', '_swagg0, PrettyFlacko_x0, ', 'post_the_legend, ', 'Edmonds33M, ', 'NickkPalazzo, mic_sebastian, briannerusso, christinaxrosex, lizsullivan14, ', 'nprnews, davidfolkenflik, WithDrake, ', 'JazzyJaz_92, ', 'AmericasCupNews, ', 'angie91_ny, ', 'LKP9841, ', 'TheMixedBunny, ', 'gmallard27, ', 'NYTMetro, ', 'listentolala, ', 'ohitskelda, ', 'brindapkhgillis, tenishawlsargea, theawxonair, alicanbamisner, ', 'DottieBoomBotti, ', 'Rudeguy18, ', 'gilchrestSAM, ', 'colomgurl23, ', 'Hop_InTheCari, ', 'VincenzoFelice2, patty5cake10, MattButera3, ChrisUnger_, ', '_ZoeWorld, ', 'payalll, ', 'scottythomsen, Matt_Manley, ', 'BethelBuzz, ', 'domwaters_x0, ', 'nbated, ', 'RFootball, ', 'JerseyDutch, ', 'Aydin65, ', 'steveaustinBSR, itsmilesbrah, ', 'Capt_n_Kurt, ', 'Uncle_Drew21, ', 'elizzzzard, ', 'Peppypetunia, ', 'EDavis24, ', 'LittleMissMamba, ', 'NewzFlash23, ', 'RFI, ', 'Emilllygibson, ', 'msmelissacusack, jenn_cusack, silberman, ', 'Risse35, ', 'GodTeixeira, ', 'JackBurtonsTEC9, iamcolinquinn, ', 'andy_hirsch, ', 'allieewilliamss, ', 'richelooloo, ', 'EfsaneShahmurad, ', 'stephsacchetti, ', 'carawaslike, ', 'nicole0leary, ', 'Joe_Da_Baller, ', 'In ...

# %%
# Mentions are put into a list of lists!

ment_list=[]

for i in x:
    y = i.split(",")
    z=[]
    for j in y:
        if j!=' ':
           z.append(j)
        
        
    ment_list.append(z)

ment_list
# Out:
# [['Live_Strong_30'],
#  ['wrath_of_rathje', ' TUCK_U_2_SLEEP'],
#  ['nclemens_02', ' OhMyDarling118'],
#  ['nicki3diesel'],
#  ['KendrickLaamar', ' JColeNC'],
#  ['JessicaNieberg1'],
#  ['GodPosts'],
#  ['Lukaymusic'],
#  ['DJ_RJCoia', ' Chris_Lansdown'],
#  ['BWebb32'],
#  ['toritoosalzman', ' roseleemcrbarbo', ' melanisiwalton', ' rufinabsmyrick'],
#  ['tumblr'],
#  ['brynardone'],
#  ['bdeabreu27', ' nikiDxoxo'],
#  ['LaCreme_x'],
#  ['scottlinn980'],
#  ['bhritcv'],
#  ['chrsphr'],
#  ['MikeBloomberg'],
#  ['sarahlawton13'],
#  ['Sophia_Fury'],
#  ['Bakes_Jamie13'],
#  ['CarolineLFerrer'],
#  ['ItsNi_thoo'],
#  ['HardInTheYard'],
#  ['LiveLoveYoshi'],
#  ['domcarusone'],
#  ['kid_polansk'],
#  ['kenzwall'],
#  ['HBO'],
#  ['MattRevenir'],
#  ['ariianababiix'],
#  ['BostonBrodes'],
#  ['NYTMetro'],
#  ['Cpt_Inshane_O'],
#  ['steponme084'],
#  ['CrysB_999', ' PaigeVicari'],
#  ['emily_wood9'],
#  ['KelseyNiz'],
#  ['okwerdz'],
#  ['TylerGalligan', ' Gucci_Steve'],
#  ['Lord_Bobbymort'],
#  ['bethanyprezioso'],
#  ['OliviaTrainor'],
#  ['MaccSuave'],
#  ['kikilovescats'],
#  ['Larwar11'],
#  ['brianjschneider'],
#  ['xo_melaniex3'],
#  ['xANDRULFx'],
#  ['AshleyEngelman'],
#  ['Timmy_Kimmy'],
#  ['megan_nehiley'],
#  ['jocelynn__xoxo'],
#  ['settak_sandy', ' BiebsUAE', ' iRou2a', ' iSalmaSmiler'],
#  ['alyssa_borrelli'],
#  ['_Mama_Cita_'],
#  ['bernicee16'],
#  ['Jenannnn'],
#  ['FarrisJamal'],
#  ['KatelynShamp'],
#  ['TessaAnzly'],
#  ['kennyMCfly'],
#  ['AleexHouviie'],
#  ['greatiscait'],
#  ['Starrkisses_'],
#  ['molinaro_p'],
#  ['EmilioBGE'],
#  ['Deannerrr'],
#  ['Mig_Lovin'],
#  ['devonedalovergi'],
#  ['Jamno233'],
#  ['mauraagz', ' CaitlynCopp08', ' ebon_yoyo'],
#  ['leyshh_3'],
#  ['im_the_TIN_mAn'],
#  ['devindakes'],
#  ['Avsp_TAC0'],
#  ['Sheikxlove'],
#  ['ajahnhuggins'],
#  ['RooneyMorris'],
#  ['realDonaldTrump'],
#  ['NiallOfficial'],
#  ['dan_ursino', ' lizzyjlucas'],
#  ['eh'],
#  ['mcuphoenix37'],
#  ['swag3katelyn'],
#  ['callmephil'],
#  ['Nataliee_Lynnx3'],
#  ['c_fabs'],
#  ['BigDaddyGraham'],
#  ['sabokitty'],
#  ['Free2Speak87'],
#  ['JTturban'],
#  ['RegularWalt'],
#  ['MarleRios'],
#  ['Griss_Martinez'],
#  ['ginaedicarlo'],
#  ['Dunn_Dylan23',
#   ' erinrin_paige',
#   ' JAD_023',
#   ' ArianaGrande',
#   ' justinbieber'],
#  ['Poooh_Beaar'],
#  ['gabefriedin'],
#  ['8765432100000'],
#  ['kail204'],
#  ['Kingz_of_Eden'],
#  ['JeffDriscoll1'],
#  ['Valerio_Aldo'],
#  ['_MandaxPanda'],
#  ['NoRegrets_16'],
#  ['svictoria24'],
#  ['MGBarbie'],
#  ['RICKTATORSHIP', ' glenmazzara'],
#  ['saraabootayy'],
#  ['GooseIsland', ' XMalibu69X'],
#  ['giibabii_17'],
#  ['NaatalieeG'],
#  ['biljacobson'],
#  ['cher'],
#  ['Terra_Cide'],
#  ['Camposssx3'],
#  ['calamariolives'],
#  ['CallMeDubstep'],
#  ['tommyklein_7', ' tori_smith8'],
#  ['ChronOfCashmere', ' unfoRETTAble', ' beeswrite'],
#  ['lisaaaharri94'],
#  ['LarryFitzgerald'],
#  ['MACproDetroit'],
#  ['AlexPonce_91'],
#  ['ali_turowsky'],
#  ['JonnySlice'],
#  ['iEstebann'],
#  ['AubreyMars_'],
#  ['RhymesUnwritten'],
#  ['cfgstw'],
#  ['_NoStylinn'],
#  ['NicoleeShonte_'],
#  ['dfr3nch', ' dev_williamson'],
#  ['CantonMass'],
#  ['realDonaldTrump', ' dennisrodman', ' CelebApprentice'],
#  ['i_WhiteGirl'],
#  ['dempseytaylor'],
#  ['chris_ganley', ' mike_crousee', ' biehl_'],
#  ['GovChristie'],
#  ['MacySullivan4'],
#  ['victoriasidotii'],
#  ['_swagg0', ' PrettyFlacko_x0'],
#  ['post_the_legend'],
#  ['Edmonds33M'],
#  ['NickkPalazzo',
#   ' mic_sebastian',
#   ' briannerusso',
#   ' christinaxrosex',
#   ' lizsullivan14'],
#  ['nprnews', ' davidfolkenflik', ' WithDrake'],
#  ['JazzyJaz_92'],
#  ['AmericasCupNews'],
#  ['angie91_ny'],
#  ['LKP9841'],
#  ['TheMixedBunny'],
#  ['gmallard27'],
#  ['NYTMetro'],
#  ['listentolala'],
#  ['ohitskelda'],
#  ['brindapkhgillis', ' tenishawlsargea', ' theawxonair', ' alicanbamisner'],
#  ['DottieBoomBotti'],
#  ['Rudeguy18'],
#  ['gilchrestSAM'],
#  ['colomgurl23'],
#  ['Hop_InTheCari'],
#  ['VincenzoFelice2', ' patty5cake10', ' MattButera3', ' ChrisUnger_'],
#  ['_ZoeWorld'],
#  ['payalll'],
#  ['scottythomsen', ' Matt_Manley'],
#  ['BethelBuzz'],
#  ['domwaters_x0'],
#  ['nbated'],
#  ['RFootball'],
#  ['JerseyDutch'],
#  ['Aydin65'],
#  ['steveaustinBSR', ' itsmilesbrah'],
#  ['Capt_n_Kurt'],
#  ['Uncle_Drew21'],
#  ['elizzzzard'],
#  ['Peppypetunia'],
#  ['EDavis24'],
#  ['LittleMissMamba'],
#  ['NewzFlash23'],
#  ['RFI'],
#  ['Emilllygibson'],
#  ['msmelissacusack', ' jenn_cusack', ' silberman'],
#  ['Risse35'],
#  ['GodTeixeira'],
#  ['JackBurtonsTEC9', ' iamcolinquinn'],
#  ['andy_hirsch'],
#  ['allieewilliamss'],
#  ['richelooloo'],
#  ['EfsaneShahmurad'],
#  ['stephsacchetti'],
#  ['carawaslike'],
#  ['nicole0leary'],
#  ['Joe_Da_Baller'],
#  ['InDueTime'],
#  ['brandilicious7', ' cyndii_wilsonn', ' HannahDionne'],
#  ['carolinekernss'],
#  ['smoothemhustla'],
#  ['DirtNasty', ' pgreene2314'],
#  ['liyahshanelle'],
#  ['kaylaa_gibbons'],
#  ['GeminisWeAre'],
#  ['YellowMansion'],
#  ['kevinjonas', ' daniellejonas'],
#  ['meeshbois'],
#  ['MarkusAlvarado'],
#  ['Steve_Campbell'],
#  ['Mr_Danny'],
#  ['CanCanMarie'],
#  ['d0mphillips'],
#  ['Mike_Melso'],
#  ['bmatuszewski'],
#  ['Joe_Leon_Stison'],
#  ['FaithfulBritt', ' MoNique_0324'],
#  ['CassieSuper'],
#  ['johndeguzman'],
#  ['Shadowfurychaos'],
#  ['Eniddxx3'],
#  ['RayJ'],
#  ['Confiident_Much'],
#  ['A_Rockk5'],
#  ['OddestFacts'],
#  ['VIXEN_VENA'],
#  ['eugeniac727'],
#  ['CamisSass', ' jawnrobinson09'],
#  ['Selena_xoOox'],
#  ['epulaski'],
#  ['mike89ny'],
#  ['ap3sss', ' corinnemangi'],
#  ['ForeverSitting_'],
#  ['Lexluvslife'],
#  ['forever_lovexox'],
#  ['julgress', ' emmagrifffin', ' MINDBLOWlNG'],
#  ['Gem_Belle'],
#  ['ruesscolleen'],
#  ['gabbymyska'],
#  ['fayshields', ' oheyitsmurph'],
#  ['PrincessLalaa'],
#  ['ShaunNerney'],
#  ['Harry_Styles'],
#  ['JeT_RoCkIt'],
#  ['VIPRaudra'],
#  ['AyeeStevee'],
#  ['JoeyDwyer14'],
#  ['ThePrestigeBeer'],
#  ['BarbieBabeeeei'],
#  ['lex_of_love'],
#  ['sabrinacorley4'],
#  ['tukicarter'],
#  ['NathanFillion'],
#  ['devonmurt'],
#  ['danbenjamin', ' TWestonKendall', ' altonbrown', ' 5by5'],
#  ['MattL523'],
#  ['wilkcmjm'],
#  ['lynnyChap'],
#  ['randolphcolon1', ' enrique22502'],
#  ['lesstiseo'],
#  ['Smuiseyyy'],
#  ['realDonaldTrump'],
#  ['xdiggyxstarx'],
#  ['cassandrapeps'],
#  ['SanRiley_'],
#  ['jasmin3ofagraba'],
#  ['BarackObama'],
#  ['Carter_Savannah'],
#  ['NiallOfficial', ' sandy_beales'],
#  ['J13Mello'],
#  ['tortor94x'],
#  ['Cupsalwaysfull', ' ClayMason9', ' FlyEaglesNation'],
#  ['mansurballs13'],
#  ['NotoriousNewell'],
#  ['Giants'],
#  ['AndyBridgeforth'],
#  ['_emiliajc'],
#  ['chef_boyar_d'],
#  ['yougot_MAKIFIED'],
#  ['ANewnez'],
#  ['bboneusa', ' chinadoll756', ' FoxNews'],
#  ['Kharan1'],
#  ['samonster914', ' SnOCherriE'],
#  ['christinacif'],
#  ['Miss_Grey_Goose',
#   ' SoaringCraneMA',
#   ' Lou_Mont_Jr',
#   ' SorayaBakhbakhi',
#   ' ericJtoro',
#   ' luisaugustovp',
#   ' Judy1020',
#   ' iamsheilareese'],
#  ['StevieSoFetch_'],
#  ['stellasensel'],
#  ['_illumiNATY'],
#  ['wmata'],
#  ['CoachBBrowner10'],
#  ['MeriamPulles'],
#  ['NICKIMINAJ'],
#  ['Bigairplane11', ' leepannone'],
#  ['joer138', ' current'],
#  ['valerie_furman', ' LoganCTashea'],
#  ['Connor_Lyons15'],
#  ['TheRealCaseyCon', ' DylanMichalek', ' TheSamCollura'],
#  ['AristeguiOnline'],
#  ['Fabu_Lyssss'],
#  ['elpuma11'],
#  ['iamtrini', ' HotepAshay'],
#  ['nikkicainn'],
#  ['Sandraaaa_A'],
#  ['Mariyux33'],
#  ['myersandchang'],
#  ['JusBlaze86'],
#  ['Authentic_Soul'],
#  ['sillytilly3'],
#  ['kylaaa_xoxo',
#   ' _mellodietorres',
#   ' sammycordero_',
#   ' ilianne_x33',
#   ' LalyXsodope'],
#  ['David_Linden'],
#  ['Sandy_Cheeks6'],
#  ['Pinhead_Larry__'],
#  ['GovernorOMalley', ' MDMEMA'],
#  ['Malo_0na'],
#  ['Im_Bang_'],
#  ['JoeyGhione'],
#  ['danielhenney'],
#  ['_donasiaM'],
#  ['brendon310'],
#  ['JaclynHALEY', ' patgrenier6'],
#  ['NBAonESPN'],
#  ['jekkkkax3'],
#  ['Bourdain'],
#  ['DownGoesAvery'],
#  ['Ddubcuffme'],
#  ['NATURALREDBONE'],
#  ['NoLeftTurns_'],
#  ['PhaedraParks', ' aurosan', ' CoryBooker'],
#  ['MagicJohnson95_'],
#  ['adeolabrittany'],
#  ['leanzaaa_x3'],
#  ['JonBibbs'],
#  ['Lakers'],
#  ['FATSBAND', ' abandonallships', ' smacfarlane5'],
#  ['SHannitysHair'],
#  ['cas_andraa'],
#  ['sychopx'],
#  ['LilKim'],
#  ['JaclynFrann'],
#  ['jessienicole32'],
#  ['kelseyyy36'],
#  ['Maritzcracker'],
#  ['need2folkus'],
#  ['taayyyyy_'],
#  ['WhiteBoyJimmy_'],
#  ['INKPAPERproblem'],
#  ['lyssaa143'],
#  ['_mylittleself'],
#  ['mikeyziggz'],
#  ['LOLGOP', ' TheDailyEdge', ' TeaPartyCat'],
#  ['YABOYMITT'],
#  ['CaitEnglish424'],
#  ['totti10forever'],
#  ['shannonperkins_'],
#  ['CPfromGV'],
#  ['lostwo0ds'],
#  ['ConcernedMom9', ' StanfordFball'],
#  ['Richie_Rowe'],
#  ['xoJessica912xo'],
#  ['BmonsterDaBeast'],
#  ['MsSugarPlums'],
#  ['MSantos_xo'],
#  ['amberfriel'],
#  ['ShelleyCHolmes'],
#  ['kaylaaayo'],
#  ['RGTF_CT'],
#  ['20ataribigby'],
#  ['Harry_Styles'],
#  ['StarLiqhtBriqht'],
#  ['chlobon', ' kihoonchung'],
#  ['MiketheTrojan'],
#  ['megs3215'],
#  ['peterdanielbeck'],
#  ['chelseylately28'],
#  ['_ImDirtyDan__x'],
#  ['cschweitz', ' mattklewis'],
#  ['Pablofra7D', ' elizabethcorado'],
#  ['gabriellavis'],
#  ['aweers'],
#  ['eclairification'],
#  ['cassrain25'],
#  ['xKailiAnne'],
#  ['mandypoo12'],
#  ['STRAWBERRYTOYA'],
#  ['_xEM15'],
#  ['JRoot00'],
#  ['doylearmbrust'],
#  ['sarah3ryan'],
#  ['reetahswaterice'],
#  ['MaziMaz92'],
#  ['bronxjT'],
#  ['Bill_Patterson1'],
#  ['Adrian_Marin8', ' MattPrice22'],
#  ['V4Daddy', ' christnemaddela'],
#  ['kayyten'],
#  ['Emm_Milcarek'],
#  ['Billy_da_Gr8'],
#  ['mmkellz', ' suchsimplew0rds'],
#  ['Jump_Off_A_Brig'],
#  ['soapsindepthcbs'],
#  ['CR34M_'],
#  ['WorstOfSag'],
#  ['RealFatherDoyle'],
#  ['BlASiiAN_B0Rii', ' ChrysAyo'],
#  ['DalizzlexO'],
#  ['Thruth'],
#  ['NYG24'],
#  ['kennychesney'],
#  ['prachant'],
#  ['GAYDOrade_', ' JoshWilliams65', ' emyers14', ' youngbergs13'],
#  ['Bayxo11'],
#  ['CandiceNicolePR'],
#  ['MikeThe_V', ' Donald_Hoover'],
#  ['taralynn6843'],
#  ['DrDogs247'],
#  ['CNET'],
#  ['UWMadison'],
#  ['carnovalerie'],
#  ['_WhittCream'],
#  ['elianneestevez'],
#  ['JFITZ21693'],
#  ['Liz_Benedict'],
#  ['wild_thangggg'],
#  ['TheRealNickMara'],
#  ['_dmoo'],
#  ['keithsjgranados', ' larraineuhmidki', ' maryjanehssjung'],
#  ['HugeGuitarWhore'],
#  ['americanapparel'],
#  ['smooch1010'],
#  ['Jailahxo'],
#  ['Kadeeavel_'],
#  ['tim_keuchler00'],
#  ['goforchazz',
#   ' R_Nuke',
#   ' _Stormin_Norman',
#   ' lkallberg',
#   ' BriLikeDaCheez'],
#  ['LindaEtTac'],
#  ['Nasislike_'],
#  ['ShutUpFarmer', ' JillY_Ya_ShawTy'],
#  ['BW'],
#  ['christinacally', ' biancaDevvs'],
#  ['_CHRIST_opher_'],
#  ['Buttercupxo_'],
#  ['InfiniteShawty'],
#  ['_noTORRious', ' AHyatt29'],
#  ['connorteneyck'],
#  ['RER403'],
#  ['Wakeand_Jake'],
#  ['UnoCinco__'],
#  ['ShaneIndeglia', ' coartneyreid'],
#  ['RealNaijabloke'],
#  ['violentlips'],
#  ['Wicked_Legit'],
#  ['LesbiTrenadee'],
#  ['J_Garhia', ' KChabs'],
#  ['MadisonMontana_'],
#  ['katcreag4NY'],
#  ['daninapss', ' stephaanieeannn'],
#  ['CreateMePink'],
#  ['MMaciolekx0'],
#  ['Jaredd_ricardoo'],
#  ['AHurricaneSandy', ' Kelsey_Payne11'],
#  ['Leilo24', ' JDelJesus25'],
#  ['lenadunham'],
#  ['Hi_imCutexO'],
#  ['KGMoeketsi'],
#  ['jeanaye'],
#  ['MrBaniRD', ' TainaPimentel21'],
#  ['C_mag30', ' ChazzyBlumpkins', ' jo_elombar_di10', ' mqrota', ' mqrota'],
#  ['FemalePains'],
#  ['terisawjtchamne',
#   ' alysonthbpinero',
#   ' cathrinerkpquic',
#   ' templeasholtzcl'],
#  ['________sammi'],
#  ['BKLYN_RudeGyal'],
#  ['diiiaannaaa4812'],
#  ['michelleelalala'],
#  ['Mannequinesque'],
#  ['CamilleHowarth'],
#  ['NiallOfficial'],
#  ['Lesley_LLiamell'],
#  ['C_Pulliam'],
#  ['KnightWhoSayzNi'],
#  ['ChathamBorough'],
#  ['JMackdaddy_'],
#  ['_anythanggoes13'],
#  ['BarackObama'],
#  ['a_martellacci'],
#  ['ally_delmonte'],
#  ['MissMopar7172', ' FaithHill'],
#  ['Laughbook'],
#  ['ArbaroFuents'],
#  ['KhaliyahShantae', ' JadieTaughtYou'],
#  ['ReblFATALE'],
#  ['Erin_Verenazi'],
#  ['SexyCandids', ' FERKNOTstyle', ' FERKNOTpres'],
#  ['babate78'],
#  ['aliciaughton'],
#  ['KevinKrowicki32'],
#  ['Real_Liam_Payne'],
#  ['AliceeKumagami'],
#  ['sean_feller'],
#  ['tortor94x'],
#  ['TeamAnari'],
#  ['Eliot_gregory', ' lexierusso23'],
#  ['CokeBoyCano5'],
#  ['Itsmeeivelisse'],
#  ['devonbarrett'],
#  ['LilSmurfette_'],
#  ['NOTIME4LilBills'],
#  ['dzariman'],
#  ['DashOfPinkk', ' ParisaMonroe'],
#  ['carrollmorelock', ' gregoriakigchri', ' lavonnagsuber'],
#  ['sampagnani'],
#  ['MikeFATS'],
#  ['storm_sandy'],
#  ['kelseymascari'],
#  ['VictoriaColongo', ' ncoylexo'],
#  ['jsmithatas'],
#  ['morgan_murphy'],
#  ['_gracefulll'],
#  ['Owen_Martin11', ' DominicTrap', ' VinnySutera'],
#  ['IJasonAlexander'],
#  ['stephtowle'],
#  ['_PRESHofPersia'],
#  ['nickotto3'],
#  ['Steph_C0yle'],
#  ['kingaaa001'],
#  ['Shay_XVIII'],
#  ['DannyMorgis'],
#  ['nnnnnatalia'],
#  ['naKITaaa_'],
#  ['Slime__Flu'],
#  ['sammieshim'],
#  ['pdOT_cash_ave'],
#  ['TylerBragg3'],
#  ['mckennaashford'],
#  ['BbyGurlTia'],
#  ['firstKINGken_'],
#  ['TooProudForLove'],
#  ['___slimshadyy'],
#  ['Paige_Turnah', ' Paige_Turnah'],
#  ['iCOACHED_KOBE'],
#  ['Bergdorfs', ' WSJ'],
#  ['SnOCherriE', ' tranceboy_johny'],
#  ['Cokeboy_Waveyy'],
#  ['Ahmed_Qurban1'],
#  ['2878Dyer'],
#  ['Almorrisnews', ' HartfordSweat'],
#  ['MzTeeGood'],
#  ['MenHumor'],
#  ['deemxreckless'],
#  ['Ayo_Judayy'],
#  ['DarenCSwisher', ' TjayDubs', ' trinastarlite'],
#  ['Rudy_dgaf'],
#  ['krissienders'],
#  ['Cafe_MochaLatte'],
#  ['POLO__SCOTTY'],
#  ['lvable_babygurl', ' zdoteverfresh', ' AIR_xo'],
#  ['Kay_Smittyy', ' amanda_hartman'],
#  ['Lizistweeting', ' foursquare'],
#  ['jsmithh75'],
#  ['Smitty_Fresh'],
#  ['RickyKeller', ' dylanTmclean'],
#  ['Azuce_172'],
#  ['Ksherm'],
#  ['lilmommatcat'],
#  ['staceyhenry7'],
#  ['PSEGdelivers'],
#  ['shityakosays'],
#  ['_iMars'],
#  ['HotLipsAlby'],
#  ['Hurricane_D_06'],
#  ['ShaneALawlor'],
#  ['ChrisGFields'],
#  ['TooSmooth4Ya_'],
#  ['_FrancisDuhh'],
#  ['MsDiva_LisaRaye'],
#  ['mollstam'],
#  ['cdebuckwild'],
#  ['MujerDEMillones'],
#  ['livcipriani'],
#  ['LouisVuitton'],
#  ['SipRozzayyy'],
#  ['TreySongz'],
#  ['ktbenner'],
#  ['InIvyWeTrust3', ' CJ_Wise'],
#  ['evanblevine'],
#  ['UKnowiLoveMe'],
#  ['MichelleeeeMora'],
#  ['itsmsmarcus'],
#  ['SpreadButter'],
#  ['JacqMartinez'],
#  ['ohmskeegan'],
#  ['CoughColdChachi'],
#  ['ProformaGuy'],
#  ['Gabz_Nain'],
#  ['DaveStefanski'],
#  ['samaral02'],
#  ['sandybeales'],
#  ['ItsWumbo'],
#  ['hoffmanrich', ' News12LI'],
#  ['andylenners'],
#  ['itsnow_Morgan'],
#  ['Marisabelli24'],
#  ['ibrahimalaslani'],
#  ['JenMaxfield7'],
#  ['Gal_Dove'],
#  ['Rageing_Demon'],
#  ['RitaDaniels69', ' EXXXOTICA'],
#  ['JakeClark33'],
#  ['QuazyBanga55'],
#  ['JaneFag16'],
#  ['brennnaroche', ' jennnytals'],
#  ['sandy_belbol'],
#  ['Harry_Styles'],
#  ['JulWasilewski'],
#  ['IzaiahHunta'],
#  ['ddlovato'],
#  ['BennytheJet_'],
#  ['itshoneyyduhhh'],
#  ['Jenner_Fans2012', ' PuppyCanadian'],
#  ['JimmySchneider', ' rgbaseball275'],
#  ['FuckkUU_PayyMee'],
#  ['its___nahomiiee'],
#  ['iSarcasmos'],
#  ['sahilkeval'],
#  ['BravoAndy'],
#  ['Koldest_Wynter'],
#  ['MikeBallisLife', ' _suckmybeautyxo'],
#  ['aj_hernandez22'],
#  ['Novisams',
#   ' SimboKAy',
#   ' a_ekawati',
#   ' sesi_basuki',
#   ' nendensaridewi',
#   ' reena_abas',
#   ' tithalitaa',
#   ' usie4sure'],
#  ['hamtoes_'],
#  ['Ricky_Pacheco9'],
#  ['_lilMalluDiva'],
#  ['politico'],
#  ['AshleighLynch90'],
#  ['Sandy_Andolong'],
#  ['rkmatchmaker'],
#  ['RealTylerGarcia'],
#  ['d0UGhERtY'],
#  ['mary_and0'],
#  ['RoseTintedVisor'],
#  ['DblockLarge'],
#  ['RoadhouseKillah'],
#  ['kaitlynnrose_', ' daishariverax3'],
#  ['princesssnikki1'],
#  ['carleybrianne'],
#  ['LoveLiveSeem'],
#  ['41ia'],
#  ['ikachan629'],
#  ['_heart2_heart', ' ReLovesNai'],
#  ['Nikotheikon'],
#  ['ItsTheSituation'],
#  ['TAStaughtme'],
#  ['HanniaKit', ' Gmseons'],
#  ['DisneyParks'],
#  ['Nick_Howard_44'],
#  ['BSingh1994'],
#  ['christinexscott', ' LindsayBourdeau'],
#  ['xolillianxo'],
#  ['Coouurrttt'],
#  ['Mariano247'],
#  ['OhItsJussLiyah'],
#  ['MountTaborFD'],
#  ['HEB_4', ' JEB_96', ' b0_9ali7', ' DFAlShammari', ' MFS_18'],
#  ['Easty102'],
#  ['IntlCrimCourt'],
#  ['Lipari22'],
#  ['MegannCinelli'],
#  ['sean7rivera'],
#  ['FANSforjana', ' kramergirl'],
#  ['gwegarm1995'],
#  ['suuwoobanga401'],
#  ['Greekysimi'],
#  ['__therealsteve'],
#  ['Fly_zaddi'],
#  ['LumyJames_'],
#  ['jordan_valerie'],
#  ['Little__Head', ' Beauty_Brains31'],
#  ['Got_HalalMeat'],
#  ['kuurtybirdy'],
#  ['_PugsNotDrugs_'],
#  ['JArvesen413'],
#  ['JenniferStec17'],
#  ['demi_joy', ' ItsMeganCrystal', ' Dnttextmyheart'],
#  ['ElTenEleven'],
#  ['Woohoo_Barz'],
#  ['cassm_craw', ' Official_TimmyP'],
#  ['_pookieeee'],
#  ['paulpierce34'],
#  ['weatherabc7'],
#  ['JadeRGalaxy'],
#  ['VanessaVanetten'],
#  ['mallllory_xoxo'],
#  ['LifeAs_RB'],
#  ['Exetercheer5'],
#  ['JocelynMarin_'],
#  ['RogerDean5'],
#  ['mjpcdhoops'],
#  ['AmazingKay29'],
#  ['CoryBooker', ' fwoodbridge'],
#  ['TheChrisPags'],
#  ['tayylangg'],
#  ['Heilig_Nick'],
#  ['jizzlelax', ' Zac_a_Dank'],
#  ['JeremyDManning'],
#  ['Bigg_TIMe'],
#  ['jcasap', ' dvillanojr'],
#  ['DreBenRich'],
#  ['arelisxo'],
#  ['kaitlynlopezx3', ' ayeJB_Bullock'],
#  ['_MattThomas'],
#  ['_luisen_', ' LaMexicoCom', ' lau_fda'],
#  ['Cara_Martin'],
#  ['ghettorapunzel'],
#  ['Ayy_Naranjooo'],
#  ['TheyCallMeSheff'],
#  ['taayleerx3', ' JennaDooleyxo'],
#  ['MA_CAMELTOE'],
#  ['Jushunter10'],
#  ['brianaaaox0'],
#  ['liftweights'],
#  ['PuppaShabba__'],
#  ['WrestleMania', ' BigKeifo', ' sseideljr'],
#  ['scruzio'],
#  ['eatA_butt'],
#  ['N_uRr'],
#  ['wormymcgaughey'],
#  ['ImJust_Melissa'],
#  ['katieecloudd'],
#  ['amandaaajoyy'],
#  ['Sophie_YupItsMe', ' Ms_DislikeU'],
#  ['D0ugieFreshh'],
#  ['KylieJenner'],
#  ['Fl00dy_Mary'],
#  ['JheneAiko'],
#  ['pereztim'],
#  ['hey_booutiful'],
#  ['feministing'],
#  ['CupcakeNarry'],
#  ['CayCay_McNitro'],
#  ['diggy_simmons', ' rickyrozay', ' officialjaden'],
#  ['xo_naomi12'],
#  ['DIJAHknow_'],
#  ['alexascher2'],
#  ['KelseyMargavich', ' leeYAHNah'],
#  ['ginaedicarlo'],
#  ['JKO424'],
#  ['waynejackson99'],
#  ['DJ_FAMOUS401'],
#  ['Frankenstorm012'],
#  ['Sara_BintAhmed'],
#  ['jmariex8'],
#  ['weight_room'],
#  ['LaSquishaD'],
#  ['Belle_Fanm88'],
#  ['americancyclo'],
#  ['oldbuzzardisgod', ' jimbobsonofgod2'],
#  ['AllegedlyRoss'],
#  ['Off_the_Cliff'],
#  ['VA_LEGEND'],
#  ['Love_Briitt'],
#  ['HiRezTheRapper'],
#  ['MsTMeLLo'],
#  ['YouTube'],
#  ['piersmorgan'],
#  ['SamSaphire_'],
#  ['VeryRudeTweets', ' zezal1'],
#  ['SandyGuerriere',
#   ' AdvertisingLaw',
#   ' bkmacdaddy',
#   ' Bridget_CooKs',
#   ' jerry_cohen',
#   ' VincentHunt',
#   ' dikeough',
#   ' FunkySteph'],
#  ['Shannonmeese1', ' _shanmariee', ' amanda_bonano', ' brittacossst'],
#  ['IHeart_GEEKS'],
#  ['jfred313'],
#  ['beautydollx0'],
#  ['UberFacts'],
#  ['Tyler_Higginss', ' Anna_h20s'],
#  ['LiLMarkyB'],
#  ['NatThe_Cat'],
#  ['LifeOfABarbie', ' mikef_insantore'],
#  ['skuBAsTEvE89'],
#  ['HOESbStruggLYNN'],
#  ['alexnoellle'],
#  ['bigredtim', ' allieharch', ' mikeyil', ' brimil', ' jaimeknowsbest'],
#  ['heysamheyy'],
#  ['tarachester1975', ' JennFredTV'],
#  ['MaggieRappleyea', ' WOWFactsOfLife'],
#  ['Haley_Howarth'],
#  ['JUSTABLACKGUYY'],
#  ['Avolyn_Elicia'],
#  ['rachelmaleady'],
#  ['DontGetFresh_'],
#  ['gcrawley', ' GeneMcVay'],
#  ['lexigoodnough9'],
#  ['joe_norm', ' UPS'],
#  ['GottaLove_Sandy'],
#  ['GSeries_Junior'],
#  ['Hamurabbi'],
#  ['piersmorgan'],
#  ['Christianolando'],
#  ['JohnMayer'],
#  ['MichaelBlackson'],
#  ['chrischristie'],
#  ['RonZimmerman_1'],
#  ['paige_kenealy'],
#  ['courtneyleach14'],
#  ['kristenturnerx'],
#  ['KevinHornePSU'],
#  ['wordofSOUF'],
#  ['TrillaGod'],
#  ['SaraSchwake'],
#  ['turkiih'],
#  ['xephero'],
#  ['jordyn_wieber'],
#  ['ls_rocha', ' KidFerz', ' So_Calli', ' MrSuckkaFree17'],
#  ['girlsposts'],
#  ['lexxx_1697'],
#  ['DylanGarguola'],
#  ['YMDgento'],
#  ['Sandy_Ruby3'],
#  ['casshaydenxo'],
#  ['ShannonGravelle', ' HashtagMagg'],
#  ['kpl26pats', ' DBurgess14'],
#  ['higohigo10'],
#  ['Real_Liam_Payne'],
#  ['taty_camara', ' daniellacamara'],
#  ['MKat16'],
#  ['CamisSass'],
#  ['youssef__23'],
#  ['russwood666', ' Nick'],
#  ['TheRealBigJim78'],
#  ['ThatOneGuy3000', ' trevor_s_hinds'],
#  ['ProfessorCorria'],
#  ['NSTAR_News'],
#  ['ospros03'],
#  ['B_Maculate'],
#  ['ctgod_gmgod'],
#  ['MegBerardelli'],
#  ['PSDoubleHoSeven', ' MarcusHaight'],
#  ['HighSt_Grill', ' NJCraftBeer'],
#  ['VictoriaCalarco'],
#  ['Gaylussite', ' AlexSteffen'],
#  ['monica_shields', ' Samantha_Fons'],
#  ['r0b_0'],
#  ['kellyransford'],
#  ['QPreston96', ' nhaag9'],
#  ['chucknorris'],
#  ['jennettemccurdy'],
#  ['KerryDonaghey'],
#  ['GinaRaimondo', ' CoryBooker'],
#  ['Timmaayyyyy', ' rebeccajenn_xo'],
#  ['KillaQueen88'],
#  ['jimmyyadig'],
#  ['Kwon_Jiyun'],
#  ['CARatelle', ' cgraff19'],
#  ['Jsine35', ' CT_Estep'],
#  ['KristiFicara'],
#  ['anchalmehra'],
#  ['danielleswingle'],
#  ['naiiyaaa'],
#  ['StevePoliti'],
#  ['DontMentionLove'],
#  ['schupperman13'],
#  ['reverend_bunnie'],
#  ['BiancaxThuglife'],
#  ['snapdragon830'],
#  ['YEAHimFROM13sT'],
#  ['AmandaMellace'],
#  ['MickieeMoscoto'],
#  ['BarackObama'],
#  ['M0zilla'],
#  ['K_Da_Giant'],
#  ['twc_hurricane', ' robertcostaNRO'],
#  ['bonjii00'],
#  ['NoellePerotti', ' JuuliaRose'],
#  ['ChanelDestinee'],
#  ['lanceeryann', ' nicoleflankkk'],
#  ['HLN'],
#  ['carlitosvilchis', ' PATRICIAPRINZ'],
#  ['BigJohnScafiddi'],
#  ['DinaDelicious'],
#  ['danidanimeow'],
#  ['CCPrezShannon', ' tylermachado'],
#  ['DT_KNODAT_HA'],
#  ['Jermeil_Jaj'],
#  ['jen_mellish', ' limpdicklang'],
#  ['zaynmalik'],
#  ['YG_Swift'],
#  ['Strong_Dividual'],
#  ['xaxxoo', ' kristefany'],
#  ['C_Byer10'],
#  ['jperzy'],
#  ['PoppaDollzz'],
#  ['Kyle_Fletcherr'],
#  ['maddierosexox'],
#  ['carbo523'],
#  ['jeffry_blake'],
#  ['michaelsburke'],
#  ['bymatthewk', ' BarackObama'],
#  ['mikemastropiero'],
#  ['dan_b4yah'],
#  ['nikkitemps'],
#  ['ryanhanrahan'],
#  ['Real_Liam_Payne'],
#  ['mikedeek', ' ArtieQuitter'],
#  ['Runcatrunn'],
#  ['MassholeSports', ' davidwent12'],
#  ['BkUNDLESS_'],
#  ['Ash_Fullerr'],
#  ['TyONeil54'],
#  ['ChrishanaFancy'],
#  ['PaulRyanVP'],
#  ['Randy_Atiyeh', ' _Chunksurdaddy_', ' Jono_Younes', ' Goodfellas19'],
#  ['______KD'],
#  ['_HazeWorld_36'],
#  ['KevinMGreen'],
#  ['lex_fanelli', ' Learr_'],
#  ['karo_05'],
#  ['CLEAR'],
#  ['ChellieDD'],
#  ['BryanSaidThat'],
#  ['xo_Kingzion713'],
#  ['ShannenBlack'],
#  ['anniebiatchxo', ' casseykane'],
#  ['MKimberger'],
#  ['iansomerhalder'],
#  ['DissedDismissed'],
#  ['allisonjustined'],
#  ['LilyTroya'],
#  ['LadyBugCharee'],
#  ['XanderjavyA'],
#  ['Tpavz'],
#  ['MannyDiaz_09'],
#  ['Phidboi'],
#  ['CoryBooker'],
#  ['sammiegaith', ' squilliumfancy'],
#  ['belladamax3'],
#  ['WalkingDead_AMC', ' talkingdead'],
#  ['Missypel024'],
#  ['SportsCenter', ' davidortiz', ' jld1002', ' TColaluca0828', ' kshorty97'],
#  ['_lyriccc_'],
#  ['BossHoggUSMC'],
#  ['sandy_favela'],
#  ['Wavyy_Montana'],
#  ['nicolefallonn'],
#  ['TeamShawnDerek'],
#  ['kaydubz7'],
#  ['itsPaulaOrtega'],
#  ['mehmethashas'],
#  ['Kristm4s'],
#  ['LillyDosanjh'],
#  ['Thatdudericky'],
#  ['History'],
#  ['_kris10xo'],
#  ['News12WC'],
#  ['kim617'],
#  ['DynaiseMarie'],
#  ['HenryStimler', ' YanaTara'],
#  ['donnybeatz27'],
#  ['sam_beth17'],
#  ['jeneerosee'],
#  ['jas0n401'],
#  ['CoolMoneyFRANK'],
#  ['willedmond'],
#  ['DolphinStroker_'],
#  ['jackierios04', ' MGTypical94'],
#  ['Olet_me_tweet', ' lvl73sleepboo'],
#  ['VictoriaBatt14'],
#  ['Relationship1O1'],
#  ['YCeciliano'],
#  ['whatthekellx0'],
#  ['gfam_fran', ' TayyibAli', ' rockiefresh', ' JahlilBeats'],
#  ['USATODAY'],
#  ['mayande01'],
#  ['appreciateboard'],
#  ['DJAndrewTroya'],
#  ['bobpetesarah'],
#  ['seannnleaheyyy'],
#  ['ryantaloa', ' KEMagana'],
#  ['natematias', ' grok_', ' mstem'],
#  ['LoveMondoTrasho', ' ProjectRunway', ' ivyhiga', ' ivyhiga'],
#  ['underbidbob'],
#  ['Forever_Sandy_'],
#  ['marchamasaki', ' elliegoulding'],
#  ['inCHARge__'],
#  ['triniqueen01', ' Socaking89', ' Kr3wboyKenz'],
#  ['aboxingfan',
#   ' TheDrDream',
#   ' nesgto',
#   ' nellynel987',
#   ' jhabeeb1',
#   ' boogiedownSHON'],
#  ['Juliaaax29'],
#  ['H3MpOverTheHill'],
#  ['TheKSanx', ' Mari_Yooo', ' ChrisMathew14'],
#  ['AdorableCalder', ' NLiloZarry'],
#  ['OHheyacdubbs'],
#  ['TomJohns15'],
#  ['Tuftsliven'],
#  ['realDonaldTrump'],
#  ['j_lynn91'],
#  ['courtdahl'],
#  ['taylorswift13'],
#  ['BostonGlobe', ' BostonGlobeMag', ' LMaggioDesign'],
#  ['BastilleMktg', ' gloriabell'],
#  ['christinaphil'],
#  ['trybalboyz'],
#  ['HelloNewBrit'],
#  ['ajordan93_', ' nicolelisa94', ' sandy_armit'],
#  ['cristianpavezd'],
#  ['baauer', ' PachaNYC'],
#  ['TrippyNigga420'],
#  ['LemonAndersen'],
#  ...]

# %%
ment_list
uname
conpair=[]    
    
for j, jval in enumerate(ment_list):
    for k in jval:
        for i, ival in enumerate(uname):
            if k==ival:
                iuser=j
                jmen=i
                if uname[iuser] in ment_list[jmen]:
                    conpair.append([uname[iuser],k])
                
            

            
print(conpair)
# Out:
# [['cassiex0ellis', 'CanCanMarie'], ['weswtf', 'FuckkUU_PayyMee'], ['weswtf', 'FuckkUU_PayyMee'], ['_AaronRenaud', 'Jushunter10'], ['_AaronRenaud', 'Jushunter10'], ['CayCay_McNitro', 'CayCay_McNitro'], ['amontecalvo_515', 'Jsine35'], ['victoriaarachel', 'LadyBugCharee'], ['mikekowalski_', 'Tpavz'], ['Kingg_Richard_', 'BallTil_IDie_LC'], ['Kingg_Richard_', 'BallTil_IDie_LC'], ['Cvman02', 'Cvman02'], ['WeAreCha', 'Alex_Spinner'], ['andnowimn0thing', 'm0ntr0se'], ['ItsSydneyBitch9', 'ShyenneSayz'], ['ItsSydneyBitch9', 'ShyenneSayz'], ['tupperbeware', 'chris_TPY'], ['SRdipalot', 'SeanPhelan5'], ['TopShelfBrews', 'TopShelfBrews'], ['alexknowshtml', 'tonybgoode'], ['becca_snell', 'erinsheaaa'], ['SuperBaddrohadd', 'SuperBaddrohadd'], ['_D1bound_', 'CjEdwardzzz'], ['MzAzure_Roblez', 'MzAzure_Roblez'], ['elilesser', 'kimberlykirn'], ['JimEck', 'JimEck'], ['TakemeasiamXo3', 'Malikk193'], ['tylerwfitch', 'mbutterf'], ['LivBieber11', 'LivBieber11'], ['RayEllisIII', 'nicoleflankkk'], ['nikkil0vezy00', 'wownicolee'], ['DDougyy', 'Megglezzz'], ['DDougyy', 'Megglezzz'], ['FreddyJ_23', 'SteffEsposito'], ['FreddyJ_23', 'SteffEsposito'], ['VickNalentino', 'krysbabyxo'], ['VickNalentino', 'krysbabyxo'], ['Paigevic5', 'classic_chick1'], ['Paigevic5', 'classic_chick1'], ['kerryann718', 'kerryann718'], ['RenAruba', 'RenAruba'], ['UncleLuke_Bitch', 'Lil_Miss_Dmples'], ['UncleLuke_Bitch', 'Lil_Miss_Dmples'], ['Tpavz', 'mikekowalski_'], ['marissagerlock', 'IamJovern'], ['DeanetteAcosta', 'Markieton97'], ['DeanetteAcosta', 'Markieton97'], ['DeanetteAcosta', 'Markieton97'], ['Sandy_cheeeeks', 'Prime_FR'], ['KaseyBrochu', 'renatatraverso'], ['KaseyBrochu', 'renatatraverso'], ['KaseyBrochu', 'renatatraverso'], ['_eileendennis', '_mariadeleon'], ['SPEAKFRIDAYS', 'SPEAKFRIDAYS'], ['the_real_me52', 'MsKerr_XOXO'], ['KBuroojy', 'lauraabritton'], ['KBuroojy', 'lauraabritton'], ['KBuroojy', 'lauraabritton'], ['KBuroojy', 'lauraabritton'], ['FOX29philly', 'ScottWilliamsTV'], ['CapeMayPoint', 'capemayblogger'], ['mccarthy_9', 'AdamKessel04'], ['mccarthy_9', 'AdamKessel04'], ['mccarthy_9', 'AdamKessel04'], ['mccarthy_9', 'AdamKessel04'], ['mccarthy_9', 'AdamKessel04'], ['mccarthy_9', 'AdamKessel04'], ['mccarthy_9', 'AdamKessel04'], ['escape', 'escape'], ['escape', 'escape'], ['erinfur', 'pistol_patches'], ['ashleighone3', 'raychcoonz'], ['xocorinaxo', 'soulartistic_'], ['xocorinaxo', 'soulartistic_'], ['xocorinaxo', 'soulartistic_'], ['xocorinaxo', 'soulartistic_'], ['mbutterf', 'tylerwfitch'], ['_ChelleyO', 'Mr_Rivs15'], ['_ChelleyO', 'Mr_Rivs15'], ['williamtuxbury', 'nickzaleski'], ['WeAreCha', 'Alex_Spinner'], ['xocorinaxo', 'soulartistic_'], ['xocorinaxo', 'soulartistic_'], ['xocorinaxo', 'soulartistic_'], ['xocorinaxo', 'soulartistic_'], ['ashlAY527', 'x0ange'], ['alexis_demolina', 'alexis_demolina'], ['GuccBiggaveli', 'GuccBiggaveli'], ['Name_JaneDoe', 'marieshantee'], ['Name_JaneDoe', 'marieshantee'], ['Name_JaneDoe', 'marieshantee'], ['danburyweather', 'snowman333'], ['danburyweather', 'snowman333'], ['danburyweather', 'snowman333'], ['chellygeronomi', 'chellygeronomi'], ['timmyselfridge', 'ItsBeccks'], ['Firehound55', 'Ants_SNEweather'], ['_tinaDeex3', 'OhOhOhItsJoHnNy'], ['Megglezzz', 'DDougyy'], ['Megglezzz', 'DDougyy'], ['Megglezzz', 'DDougyy'], ['Megglezzz', 'DDougyy'], ['Megglezzz', 'DDougyy'], ['Megglezzz', 'DDougyy'], ['JordanCruser', 'JessLecerf1'], ['NutellaEnVogue', 'NutellaEnVogue'], ['jennnastfrancis', 'darlannennalrad'], ['LlyssaLove1020', 'Holla_Devin'], ['LlyssaLove1020', 'Holla_Devin'], ['LlyssaLove1020', 'Holla_Devin'], ['LlyssaLove1020', 'Holla_Devin'], ['LlyssaLove1020', 'Holla_Devin'], ['LlyssaLove1020', 'Holla_Devin'], ['LlyssaLove1020', 'Holla_Devin'], ['LlyssaLove1020', 'Holla_Devin'], ['LlyssaLove1020', 'Holla_Devin'], ['LlyssaLove1020', 'Holla_Devin'], ['LlyssaLove1020', 'Holla_Devin'], ['LlyssaLove1020', 'Holla_Devin'], ['LlyssaLove1020', 'Holla_Devin'], ['LlyssaLove1020', 'Holla_Devin'], ['ovega95', 'DaBoulNickyD'], ['ovega95', ' ...

# %%
len(conpair)
# Out:
# 1687

# %%
import csv

with open("geo_con.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(conpair)
