# %%
pwd
# Out:
# '/Users/dharanisethuram/SamplePro/AdvConversation'

# %%
import numpy as np
import pandas as pd

# %%
df =  pd.read_csv('sandy_geo_sample200k.csv')

# %%
d = df[['Username','Klout Score']]

# %%
d.to_csv("geo_UserKS.csv")

# %%
dfr = pd.read_csv('geo_UserKS.csv')

# %%
dfr[0:5]
# Out:
#    Unnamed: 0        Username  Klout Score
# 0           0      C_lorennxx           50
# 1           1  iSlapThirsties           57
# 2           2  JACK_in_ur_box           46
# 3           3         KseniaL           54
# 4           4  andrew_dangelo           42

# %%
dfr = dfr.drop('Unnamed: 0', axis = 1)

# %%
dfr.columns = ['Username', 'KloutScore']

# %%
#DataFrame.to_dict(orient='dict')[source]
#dfr.to_dict(orient='dict')
thisdict = dict(zip(dfr.Username, dfr.KloutScore))

# %%
print (thisdict)
# Out:
# {'C_lorennxx': 50, 'iSlapThirsties': 57, 'JACK_in_ur_box': 45, 'KseniaL': 54, 'andrew_dangelo': 41, 'clalicata17': 29, 'shann_mc3': 34, 'caffeinehusky': 56, 'RDietz5': 41, 'RodneyWren': 52, 'torilussier': 38, 'intercomithaca': 35, 'gabbbiee': 44, 'MuzikGenius101': 37, 'lorisqcwyost': 10, 'AyoooooMont': 41, 'laurencasale_': 31, 'BabetteKD': 59, 'primerAngolano': 33, 'sammie_ce': 39, 'orbiqa': 0, 'LalaMada1': 32, 'shakiadnphoenix': 10, 'FilPalma': 41, 'abvanderziel': 40, 'Martijfree304': 20, 'GCoss5': 42, 'Asap_Mamba_': 38, 'nirhalegi': 0, 'kathrynminer15': 33, 'Sedated_Dreams': 41, 'johnwehler': 42, 'hoswell_Mufc': 47, 'ItchinForPaper': 40, 'CarolSohn': 30, 'RaganErricca_': 38, 'metink5': 36, 'one_spicy_nacho': 43, 'curtis_lexi': 34, 'Patriciaxo0': 33, 'skinsken': 12, 'Rosemaryrr': 43, 'yulieee3': 42, 'TiffanyStack3': 42, '__Moochieee': 45, 'CulinaryBadBoy': 44, 'jonvox': 58, 'JStoltzfus91497': 30, 'Kyle4994': 34, 'neilvogel': 59, 'clownshaveafros': 37, 'AshleighMarie31': 11, 'christiannnh': 43, 'StopTwatchin215': 42, 'LlyssaLove1020': 28, 'Ptb_Quack': 38, 'h3lik0nia': 45, 'VeeTee14': 29, 'robgchill': 17, 'Corey12551': 28, 'Mail__man': 41, 'KCMJournalist': 48, 'Jasssminnn_': 43, 'Todd_SimmonsNYC': 52, 'oddFuture__97': 41, 'SanabriaLizbeth': 41, 'SeanTaylorNice': 19, 'LilMissClassyy': 44, 'Young_Boss501': 52, 'davehalikman': 41, 'JessicaZima': 34, '_SVMMYSXSV': 41, 'GoldstarBoston': 45, 'Greaszy_Desy189': 39, 'ThatGuy_AFlyy': 45, 'kristaa424': 43, 'doinbigthings21': 27, 'OB3Y_BOOKIE': 41, 'vargasteph': 40, 'TayRob10': 0, 'sports_247365': 41, 'Liz_Quintela': 45, 'KaraPaisley': 38, 'CaseyCoudrey': 31, 'cory1976': 61, 'nataliegallops': 47, 'alexaacho': 38, 'littlewb29': 38, 'andreajmathias': 51, 'BigHerk106': 24, 'MALfunctionnnn': 40, 'Zack_Morrow_': 40, 'CorrineVicari': 43, 'daniclarkk94': 41, 'Kristen_iDo': 30, 'PabloBleedBlue3': 42, 'KamilContreras': 40, 'KelseyForgione': 39, 'ADuff36': 42, 'ficcadentii': 41, 'courtbeauty22': 44, 'Holmes855': 42, 'Im_thtGurl_Kee': 28, 'Big_Burnsy12': 38, 'Fittedheadsnc96': 38, 'therealDSnydes': 40, 'Mr_Nonchalantt': 46, 'OhHeyItsLilly': 50, 'luckychicken': 24, 'markie_vega': 37, '__samanthaa_': 32, 'doubleeGs': 39, 'XioomaraCruz': 42, 'dangarvey24': 44, 'R_Dim_2': 42, '_corinnepatt': 35, 'BangsWitMe': 51, 'kelseamorgann': 41, 'WhoGabe': 43, 'alecperkins': 54, '_XoNataMalik_': 43, 'hbn44hoover': 10, 'xKeylaDuarte': 37, 'QuannyJetLife': 63, 'NotPreston': 42, 'Jojo_bayb33': 31, 'MMG_RJ26': 32, 'KatySaam': 25, 'jcbivins': 63, 'R3daBook': 33, 'Famous_Dave314': 48, 'THAONEYUNEED24': 31, 'NiffieTiffie': 37, 'cyyann_': 35, 'BlackxxDynamite': 42, 'SaggmeisterFlex': 36, 'ItsKatieWadie': 52, 'safroota': 43, 'mcadxms': 43, 'RaechelMorgan': 33, 'TacCityBitch': 45, 'AARONSTIXSMITH': 44, 'albina_kica': 36, 'BDesaulnier34': 36, 'ReggieDaSecond': 33, 'mike_bojko': 38, 'ashleyjoaraya': 37, 'CORINNEGABPATTI': 42, 'becca_buenoo': 36, 'iAmEliudus': 35, 'GigiDiRe': 19, 'xStinkfacex': 36, '_mirandalynch_': 29, 'Dr_ChrisMagboo': 36, 'alanalindsayz': 30, 'Rason_WhoBetta': 38, 'SleazyXX': 47, 'k_vaughnn': 41, 'TeamSeXysCrisA': 43, 'lonny_johnson': 29, 'emandigo': 36, 'chronickaran': 42, 'ashtonlynn125': 42, 'kushcannon': 40, 'smnthmtthws': 40, 'ShondaShavonn': 47, 'MVPeeps': 50, 'ChewConnor': 42, 'NicoleeReed13': 33, 'duffy_kelly': 36, 'kailacarlone': 47, 'Ayyo_Smokeyy': 43, 'David_NoRuffN': 45, 'jascarro': 41, 'melimel_coolkid': 35, 'outlawedoffroad': 24, 'Basil_foreal': 42, 'TinaAlexiss': 38, 'Kwame_Banks': 39, 'MorganSup': 28, 'UrBoyHerb': 39, 'BrittaFountain': 28, 'wilsonreps': 45, 'russdiamond': 28, 'WorcesterBarFx': 33, 'BillyGunn_Vell': 43, 'Lalalexii1': 34, 'citizensconnect': 39, 'MissAmberBabyXO': 41, 'Btags92': 17, 'TullyShane': 40, 'She_Wants_The_J': 44, 'Jay_Higgs11': 36, 'gobnmholve': 0, 'RCabrey': 27, 'PiiNK_Dollaz': 48, 'mikemccabe2': 47, 'james_covey': 27, 'GratuitousFREAK': 35, 'Dezzy_Crazy': 42, 'Erikawiz': 36, 'MollyWakefield': 46, 'jackiegheraldi': 43, 'kenbalestrieri': 40, 'Thuggasaurus': 43, 'kalinp ...

# %%
thisdict['luckychicken']
# Out:
# 24

# %%
df = pd.read_csv('cleangeo_con.csv')

# %%
df[0:5]
# Out:
#    Unnamed: 0    cassiex0ellis      CanCanMarie
# 0           0           weswtf  FuckkUU_PayyMee
# 1           2     _AaronRenaud      Jushunter10
# 2           4   CayCay_McNitro   CayCay_McNitro
# 3           5  amontecalvo_515          Jsine35
# 4           6  victoriaarachel    LadyBugCharee

# %%
c= ['Username1', 'Username2']

# %%
df1 = pd.read_csv('cleangeo_con.csv', names=c, header=None)

# %%
df1.to_csv('cleangeo_con.csv')

# %%
#df2 = pd.read_csv('cleangeo_con.csv')
#df2

# %%
#df =df.drop('Unnamed: 0', axis = 1)

# %%
#df.columns = ['Username1', 'Username2']

# %%
df1["KloutScore"] = ''

# %%
df1[0:5]
# Out:
#            Username1        Username2 KloutScore
# 0.0           weswtf  FuckkUU_PayyMee
# 2.0     _AaronRenaud      Jushunter10
# 4.0   CayCay_McNitro   CayCay_McNitro
# 5.0  amontecalvo_515          Jsine35

# %%
for index,row in df1.iterrows():
    
    p = row['Username2']
    #print (p)
    k = thisdict[p]
   # print(p,k)
    row['KloutScore'] = k
    print (row)
# Out:
# Username1     cassiex0ellis
# Username2       CanCanMarie
# KloutScore               46
# Name: nan, dtype: object
# Username1              weswtf
# Username2     FuckkUU_PayyMee
# KloutScore                 37
# Name: 0.0, dtype: object
# Username1     _AaronRenaud
# Username2      Jushunter10
# KloutScore              37
# Name: 2.0, dtype: object
# Username1     CayCay_McNitro
# Username2     CayCay_McNitro
# KloutScore                32
# Name: 4.0, dtype: object
# Username1     amontecalvo_515
# Username2             Jsine35
# KloutScore                 32
# Name: 5.0, dtype: object
# Username1     victoriaarachel
# Username2       LadyBugCharee
# KloutScore                 34
# Name: 6.0, dtype: object
# Username1     mikekowalski_
# Username2             Tpavz
# KloutScore               44
# Name: 7.0, dtype: object
# Username1      Kingg_Richard_
# Username2     BallTil_IDie_LC
# KloutScore                 37
# Name: 8.0, dtype: object
# Username1     Cvman02
# Username2     Cvman02
# KloutScore         16
# Name: 10.0, dtype: object
# Username1         WeAreCha
# Username2     Alex_Spinner
# KloutScore              37
# Name: 11.0, dtype: object
# Username1     andnowimn0thing
# Username2            m0ntr0se
# KloutScore                 50
# Name: 12.0, dtype: object
# Username1     ItsSydneyBitch9
# Username2         ShyenneSayz
# KloutScore                 46
# Name: 13.0, dtype: object
# Username1     tupperbeware
# Username2        chris_TPY
# KloutScore              38
# Name: 15.0, dtype: object
# Username1       SRdipalot
# Username2     SeanPhelan5
# KloutScore             36
# Name: 16.0, dtype: object
# Username1     TopShelfBrews
# Username2     TopShelfBrews
# KloutScore               21
# Name: 17.0, dtype: object
# Username1     alexknowshtml
# Username2        tonybgoode
# KloutScore               61
# Name: 18.0, dtype: object
# Username1     becca_snell
# Username2      erinsheaaa
# KloutScore             36
# Name: 19.0, dtype: object
# Username1     SuperBaddrohadd
# Username2     SuperBaddrohadd
# KloutScore                 42
# Name: 20.0, dtype: object
# Username1       _D1bound_
# Username2     CjEdwardzzz
# KloutScore             34
# Name: 21.0, dtype: object
# Username1     MzAzure_Roblez
# Username2     MzAzure_Roblez
# KloutScore                43
# Name: 22.0, dtype: object
# Username1        elilesser
# Username2     kimberlykirn
# KloutScore              20
# Name: 23.0, dtype: object
# Username1     JimEck
# Username2     JimEck
# KloutScore        30
# Name: 24.0, dtype: object
# Username1     TakemeasiamXo3
# Username2          Malikk193
# KloutScore                31
# Name: 25.0, dtype: object
# Username1     tylerwfitch
# Username2        mbutterf
# KloutScore             64
# Name: 26.0, dtype: object
# Username1     LivBieber11
# Username2     LivBieber11
# KloutScore             40
# Name: 27.0, dtype: object
# Username1       RayEllisIII
# Username2     nicoleflankkk
# KloutScore               39
# Name: 28.0, dtype: object
# Username1     nikkil0vezy00
# Username2        wownicolee
# KloutScore               44
# Name: 29.0, dtype: object
# Username1       DDougyy
# Username2     Megglezzz
# KloutScore           43
# Name: 30.0, dtype: object
# Username1        FreddyJ_23
# Username2     SteffEsposito
# KloutScore               36
# Name: 32.0, dtype: object
# Username1     VickNalentino
# Username2        krysbabyxo
# KloutScore               44
# Name: 34.0, dtype: object
# Username1          Paigevic5
# Username2     classic_chick1
# KloutScore                40
# Name: 36.0, dtype: object
# Username1     kerryann718
# Username2     kerryann718
# KloutScore             31
# Name: 38.0, dtype: object
# Username1     RenAruba
# Username2     RenAruba
# KloutScore          45
# Name: 39.0, dtype: object
# Username1     UncleLuke_Bitch
# Username2     Lil_Miss_Dmples
# KloutScore                 46
# Name: 40.0, dtype: object
# Username1             Tpavz
# Username2     mikekowalski_
# KloutScore               34
# Name: 42.0, dtype: object
# Username1     marissagerlock
# Username2          IamJovern
# KloutScore                43
# Name: 43.0, dtype: object
# Username1     DeanetteAcosta
# Username2        Markieton97
# KloutScore                40
# Name: 44.0, dtype: object
# Username1     Sandy_cheeeeks
# Username2           Prime_FR
# KloutScore                40
# Name: 47.0, dtype: object
# Username1        KaseyBrochu
# Username2     renatatraverso
# KloutScore                44
# Name: 48.0, dtype: object
# Username1     _eileendennis
# Username2      _mariadeleon
# KloutScore               44
# Name: 51.0, dtype: object
# Username1     SPEAKFRIDAYS
# Username2     SPEAKFRIDAYS
# KloutScore              45
# Name: 52.0, dtype: object
# Username1     the_real_me52
# Username2       MsKerr_XOXO
# KloutScore               42
# Name: 53.0, dtype: object
# Username1          KBuroojy
# Username2     lauraabritton
# KloutScore               46
# Name: 54.0, dtype: object
# Username1         FOX29philly
# Username2     ScottWilliamsTV
# KloutScore                 46
# Name: 58.0, dtype: object
# Username1       CapeMayPoint
# Username2     capemayblogger
# KloutScore                44
# Name: 59.0, dtype: object
# Username1       mccarthy_9
# Username2     AdamKessel04
# KloutScore              33
# Name: 60.0, dtype: object
# Username1     escape
# Username2     escape
# KloutScore        56
# Name: 67.0, dtype: object
# Username1            erinfur
# Username2     pistol_patches
# KloutScore                44
# Name: 69.0, dtype: object
# Username1     ashleighone3
# Username2       raychcoonz
# KloutScore              44
# Name: 70.0, dtype: object
# Username1        xocorinaxo
# Username2     soulartistic_
# KloutScore               42
# Name: 71.0, dtype: object
# Username1        mbutterf
# Username2     tylerwfitch
# KloutScore             62
# Name: 75.0, dtype: object
# Username1     _ChelleyO
# Username2     Mr_Rivs15
# KloutScore           44
# Name: 76.0, dtype: object
# Username1     williamtuxbury
# Username2        nickzaleski
# KloutScore                46
# Name: 78.0, dtype: object
# Username1     ashlAY527
# Username2        x0ange
# KloutScore           37
# Name: 84.0, dtype: object
# Username1     alexis_demolina
# Username2     alexis_demolina
# KloutScore                 24
# Name: 85.0, dtype: object
# Username1     GuccBiggaveli
# Username2     GuccBiggaveli
# KloutScore               45
# Name: 86.0, dtype: object
# Username1     Name_JaneDoe
# Username2     marieshantee
# KloutScore              43
# Name: 87.0, dtype: object
# Username1     danburyweather
# Username2         snowman333
# KloutScore                42
# Name: 90.0, dtype: object
# Username1     chellygeronomi
# Username2     chellygeronomi
# KloutScore                39
# Name: 93.0, dtype: object
# Username1     timmyselfridge
# Username2          ItsBeccks
# KloutScore                46
# Name: 94.0, dtype: object
# Username1         Firehound55
# Username2     Ants_SNEweather
# KloutScore                 52
# Name: 95.0, dtype: object
# Username1          _tinaDeex3
# Username2     OhOhOhItsJoHnNy
# KloutScore                 52
# Name: 96.0, dtype: object
# Username1     Megglezzz
# Username2       DDougyy
# KloutScore           58
# Name: 97.0, dtype: object
# Username1     JordanCruser
# Username2      JessLecerf1
# KloutScore              46
# Name: 103.0, dtype: object
# Username1     NutellaEnVogue
# Username2     NutellaEnVogue
# KloutScore                49
# Name: 104.0, dtype: object
# Username1     jennnastfrancis
# Username2     darlannennalrad
# KloutScore                 47
# Name: 105.0, dtype: object
# Username1     LlyssaLove1020
# Username2        Holla_Devin
# KloutScore                34
# Name: 106.0, dtype: object
# Username1          ovega95
# Username2     DaBoulNickyD
# KloutScore              42
# Name: 120.0, dtype: object
# Username1     NikkiDelano
# Username2     NikkiDelano
# KloutScore             66
# Name: 122.0, dtype: object
# Username1     madisonhayesabc
# Username2            lyssmean
# KloutScore                 44
# Name: 123.0, dtype: object
# Username1     feelLYNN_myself
# Username2        Qaadi_Stoner
# KloutScore                 35
# Name: 124.0, dtype: object
# Username1     djbstylzz
# Username2     DjCrysis_
# KloutScore           45
# Name: 126.0, dtype: object
# Username1     BombAssAsia
# Username2     tayanichole
# KloutScore             25
# Name: 127.0, dtype: object
# Username1     MsLiryc
# Username2     MexiRHO
# KloutScore          0
# Name: 128.0, dtype: object
# Username1     OhOhOhItsJoHnNy
# Username2          _tinaDeex3
# KloutScore                 45
# Name: 130.0, dtype: object
# Username1     curious_gorgee
# Username2      chrisssssteen
# KloutScore                34
# Name: 135.0, dtype: object
# Username1     TheTriangle
# Username2     TheTriangle
# KloutScore             53
# Name: 136.0, dtype: object
# Username1     KatrinaaElly
# Username2        SoapNSoda
# KloutScore              48
# Name: 137.0, dtype: object
# Username1     DonMagicDraper
# Username2         GTheBandit
# KloutScore                45
# Name: 139.0, dtype: object
# Username1     helloiamamerica
# Username2     yosupaaronheard
# KloutScore                 44
# Name: 140.0, dtype: object
# Username1     nidiuh24
# Username2     nidiuh24
# KloutScore          23
# Name: 141.0, dtype: object
# Username1     ALC0RT3Z
# Username2     ALC0RT3Z
# KloutScore          10
# Name: 142.0, dtype: object
# Username1       moleculo77
# Username2     EddieEaw1204
# KloutScore              17
# Name: 143.0, dtype: object
# Username1      Jackieeex43
# Username2     CapriMcQueen
# KloutScore              27
# Name: 144.0, dtype: object
# Username1     bubsxgreen
# Username2     bubsxgreen
# KloutScore            44
# Name: 145.0, dtype: object
# Username1     chinupstandtall
# Username2     satanofsuburbia
# KloutScore                 40
# Name: 146.0, dtype: object
# Username1      _SarahNichole
# Username2     ArielAnnalisa_
# KloutScore                40
# Name: 149.0, dtype: object
# Username1     SmoothVic_
# Username2     SmoothVic_
# KloutScore            43
# Name: 150.0, dtype: object
# Username1     lalaleela
# Username2      Cait_Fox
# KloutScore           41
# Name: 151.0, dtype: object
# Username1     ThurlAddiction_
# Username2              _Eshli
# KloutScore                 47
# Name: 152.0, dtype: object
# Username1     gemorios
# Username2     gemorios
# KloutScore          11
# Name: 154.0, dtype: object
# Username1         ShyenneSayz
# Username2     ItsSydneyBitch9
# KloutScore                 42
# Name: 155.0, dtype: object
# Username1        frostyLQ
# Username2     _illuminare
# KloutScore             36
# Name: 159.0, dtype: object
# Username1      bobalcus
# Username2     canes4184
# KloutScore           20
# Name: 160.0, dtype: object
# Username1     mrs_depp97
# Username2     mrs_depp97
# KloutScore            31
# Name: 161.0, dtype: object
# Username1     JoshuaWaynex
# Username2        black_KRO
# KloutScore              43
# Name: 162.0, dtype: object
# Username1     STORMSWAG
# Username2     STORMSWAG
# KloutScore           30
# Name: 163.0, dtype: object
# Username1          GabieKur
# Username2     kortney_renee
# KloutScore               44
# Name: 164.0, dtype: object
# Username1     Nikita_Penelope
# Username2          jvargas108
# KloutScore                 18
# Name: 165.0, dtype: object
# Username1     valeryximenaa_
# Username2         lindsaayym
# KloutScore                38
# Name: 167.0, dtype: object
# Username1     rinimarwini
# Username2     ihsantarore
# KloutScore             64
# Name: 168.0, dtype: object
# Username1          gfxmuma
# Username2     davanique123
# KloutScore              23
# Name: 169.0, dtype: object
# Username1     LaurenNicoleex3
# Username2       lalalexieeex3
# KloutScore                 40
# Name: 174.0, dtype: object
# Username1     Bloodykidb
# Username2      emi_xoxo_
# KloutScore            36
# Name: 175.0, dtype: object
# Username1        meilynx33
# Username2     StarGang_617
# KloutScore              37
# Name: 176.0, dtype: object
# Username1     candaceide
# Username2      AdotLovee
# KloutScore            41
# Name: 177.0, dtype: object
# Username1     Fl1ck_mybic
# Username2     Fl1ck_mybic
# KloutScore             34
# Name: 178.0, dtype: object
# Username1     clbrooks13
# Username2     clbrooks13
# KloutScore            30
# Name: 179.0, dtype: object
# Username1       WTFkrissy
# Username2     pa_davis101
# KloutScore             29
# Name: 180.0, dtype: object
# Username1         otome_chan
# Username2     HarmoniaSparks
# KloutScore                25
# Name: 183.0, dtype: object
# Username1      bettycasey1
# Username2     karissavelez
# KloutScore              44
# Name: 185.0, dtype: object
# Username1         TDeeter24
# Username2     Angelaaa_xoXO
# KloutScore               53
# Name: 187.0, dtype: object
# Username1     kristanntaylorr
# Username2       stephwhitey21
# KloutScore                 35
# Name: 188.0, dtype: object
# Username1         kiinnnky
# Username2     PaulDooley_5
# KloutScore              36
# Name: 189.0, dtype: object
# Username1     chersan00
# Username2      Lugadu75
# KloutScore           54
# Name: 190.0, dtype: object
# Username1     kimberlykirn
# Username2        elilesser
# KloutScore              34
# Name: 191.0, dtype: object
# Username1     FuckkUU_PayyMee
# Username2              weswtf
# KloutScore                 26
# Name: 192.0, dtype: object
# Username1     kaylablakely
# Username2       kailyndill
# KloutScore              36
# Name: 197.0, dtype: object
# Username1     Ladivon31Von
# Username2     Ladivon31Von
# KloutScore              34
# Name: 198.0, dtype: object
# Username1     TiffanySantora
# Username2     TiffanySantora
# KloutScore                34
# Name: 199.0, dtype: object
# Username1        tonybgoode
# Username2     alexknowshtml
# KloutScore                0
# Name: 200.0, dtype: object
# Username1     ParisPlum
# Username2     ParisPlum
# KloutScore           40
# Name: 201.0, dtype: object
# Username1     MercuryX
# Username2     MercuryX
# KloutScore          57
# Name: 203.0, dtype: object
# Username1       Paulsch55
# Username2     Ste_Ven_ino
# KloutScore             25
# Name: 208.0, dtype: object
# Username1     RyanStiffield
# Username2     IvoryNRoberts
# KloutScore               33
# Name: 209.0, dtype: object
# Username1     RogNyc77
# Username2     RogNyc77
# KloutScore          28
# Name: 212.0, dtype: object
# Username1       2FLY2BDEPRESS
# Username2     cookiemunstahh_
# KloutScore                 40
# Name: 213.0, dtype: object
# Username1      SeanPKennedy2
# Username2     VinnyLatorraca
# KloutScore                41
# Name: 214.0, dtype: object
# Username1     Breety5
# Username2     Breety5
# KloutScore         43
# Name: 215.0, dtype: object
# Username1       LynDenise
# Username2     sexychanzii
# KloutScore             42
# Name: 216.0, dtype: object
# Username1     Jaymillz22
# Username2         jenali
# KloutScore            48
# Name: 217.0, dtype: object
# Username1          MarkChainz
# Username2     BallTil_IDie_LC
# KloutScore                 37
# Name: 218.0, dtype: object
# Username1     tomEfuckinDoiT
# Username2      wesleykriebel
# KloutScore                23
# Name: 224.0, dtype: object
# Username1     AnnieMesale
# Username2     AnnieMesale
# KloutScore             32
# Name: 225.0, dtype: object
# Username1         snowman333
# Username2     danburyweather
# KloutScore                49
# Name: 226.0, dtype: object
# Username1     jefflev99
# Username2     jefflev99
# KloutScore           15
# Name: 228.0, dtype: object
# Username1     RockBottomHC
# Username2     RockBottomHC
# KloutScore              48
# Name: 229.0, dtype: object
# Username1     VerifiedIPS_xo
# Username2     VerifiedIPS_xo
# KloutScore                39
# Name: 230.0, dtype: object
# Username1     austenkeim
# Username2      stephkise
# KloutScore            51
# Name: 231.0, dtype: object
# Username1     tatum_goodyear
# Username2     julie_costello
# KloutScore                36
# Name: 232.0, dtype: object
# Username1     vivalacaitybaby
# Username2      Honduras_Jay21
# KloutScore                 37
# Name: 236.0, dtype: object
# Username1     cakovalkoski
# Username2           Landon
# KloutScore              46
# Name: 238.0, dtype: object
# Username1     marieshantee
# Username2     Name_JaneDoe
# KloutScore              36
# Name: 239.0, dtype: object
# Username1          kellycsogi
# Username2     nicolemartignet
# KloutScore                 41
# Name: 243.0, dtype: object
# Username1     matthewlondono
# Username2           EzBlazin
# KloutScore                45
# Name: 244.0, dtype: object
# Username1     Amierah
# Username2     Amierah
# KloutScore         60
# Name: 245.0, dtype: object
# Username1      jaclynxanne
# Username2     allylouwhox3
# KloutScore              48
# Name: 246.0, dtype: object
# Username1       D_Booze
# Username2     brijet420
# KloutScore           33
# Name: 248.0, dtype: object
# Username1     darlannennalrad
# Username2         sirpunxalot
# KloutScore                 37
# Name: 249.0, dtype: object
# Username1       xlauragrac3
# Username2     allybabycakes
# KloutScore               33
# Name: 252.0, dtype: object
# Username1     mattbedross
# Username2     Asavocchi21
# KloutScore             27
# Name: 253.0, dtype: object
# Username1       KatyAlpino
# Username2     alisongracew
# KloutScore              40
# Name: 254.0, dtype: object
# Username1     IvoryNRoberts
# Username2     RyanStiffield
# KloutScore               43
# Name: 255.0, dtype: object
# Username1     alyssatursi
# Username2        dgrillon
# KloutScore             41
# Name: 256.0, dtype: object
# Username1     iMechanicJDM
# Username2       Wild_Onex3
# KloutScore              41
# Name: 257.0, dtype: object
# Username1     lanaaabanana
# Username2     lanaaabanana
# KloutScore              34
# Name: 258.0, dtype: object
# Username1     SpaceHead_Shvdd
# Username2     SpaceHead_Shvdd
# KloutScore                 39
# Name: 259.0, dtype: object
# Username1     Emii_Garcia95
# Username2     SneakyPratiki
# KloutScore               38
# Name: 264.0, dtype: object
# Username1     iAMiPOP
# Username2     iAMiPOP
# KloutScore         43
# Name: 266.0, dtype: object
# Username1     Iwalk_u_watch1
# Username2     Iwalk_u_watch1
# KloutScore                14
# Name: 267.0, dtype: object
# Username1     BonnieRapaport
# Username2     BonnieRapaport
# KloutScore                17
# Name: 268.0, dtype: object
# Username1       _BtwImMyshaa
# Username2     _iFrenchInhale
# KloutScore                42
# Name: 269.0, dtype: object
# Username1     AdamKessel04
# Username2       mccarthy_9
# KloutScore              43
# Name: 270.0, dtype: object
# Username1     Saserella
# Username2        Amtrak
# KloutScore           90
# Name: 273.0, dtype: object
# Username1      BrittMlaka
# Username2     Paddy_Crean
# KloutScore             34
# Name: 274.0, dtype: object
# Username1         sirpunxalot
# Username2     darlannennalrad
# KloutScore                 47
# Name: 275.0, dtype: object
# Username1       bmx24seven
# Username2     joseridesbmx
# KloutScore              36
# Name: 278.0, dtype: object
# Username1      EmilSmileCheez
# Username2     katherine_roman
# KloutScore                 40
# Name: 279.0, dtype: object
# Username1        esulek80
# Username2     DavidWilzJr
# KloutScore             29
# Name: 283.0, dtype: object
# Username1     kfrizzz
# Username2     kfrizzz
# KloutScore         43
# Name: 287.0, dtype: object
# Username1     AniseSmith
# Username2     AniseSmith
# KloutScore            69
# Name: 288.0, dtype: object
# Username1     FAMU_CSA
# Username2     FAMU_CSA
# KloutScore          39
# Name: 289.0, dtype: object
# Username1     page_human
# Username2      PeteShizz
# KloutScore            43
# Name: 290.0, dtype: object
# Username1     dizzaylizzayyy
# Username2          bigjoe_95
# KloutScore                29
# Name: 292.0, dtype: object
# Username1     BruggerA
# Username2     BruggerA
# KloutScore          43
# Name: 293.0, dtype: object
# Username1     spartadiamond10
# Username2             saigee3
# KloutScore                 37
# Name: 294.0, dtype: object
# Username1     DeanoTweetWhat
# Username2     SamanthaaDuffy
# KloutScore                42
# Name: 295.0, dtype: object
# Username1     CharlieSoBoojie
# Username2     ItsBRI_CuzImHot
# KloutScore                 35
# Name: 297.0, dtype: object
# Username1     Caramel_Keash
# Username2     YoungLeek_609
# KloutScore               40
# Name: 298.0, dtype: object
# Username1     HoCoGov
# Username2     HoCoGov
# KloutScore         49
# Name: 299.0, dtype: object
# Username1     Shortyjess94
# Username2        caritoxx3
# KloutScore              27
# Name: 306.0, dtype: object
# Username1     SamanthaaDuffy
# Username2     DeanoTweetWhat
# KloutScore                41
# Name: 307.0, dtype: object
# Username1     ariramku
# Username2     gsantino
# KloutScore          37
# Name: 309.0, dtype: object
# Username1     LBrownholtz
# Username2      MattlyWCCC
# KloutScore             35
# Name: 310.0, dtype: object
# Username1     katherine_roman
# Username2      EmilSmileCheez
# KloutScore                 35
# Name: 311.0, dtype: object
# Username1             Makaa_L
# Username2     DarielleRosario
# KloutScore                 35
# Name: 315.0, dtype: object
# Username1     _maddieberrioxo
# Username2        SamSchoepfer
# KloutScore                 44
# Name: 316.0, dtype: object
# Username1     CauseISingle
# Username2       MonRolle95
# KloutScore              40
# Name: 317.0, dtype: object
# Username1        alexabranco
# Username2     ericaleighfred
# KloutScore                36
# Name: 318.0, dtype: object
# Username1        dgrillon
# Username2     alyssatursi
# KloutScore             40
# Name: 320.0, dtype: object
# Username1          ewood02
# Username2     patricktrack
# KloutScore              52
# Name: 321.0, dtype: object
# Username1     Randydiamondz
# Username2     Randydiamondz
# KloutScore               44
# Name: 322.0, dtype: object
# Username1     AccessoryNews
# Username2     AccessoryNews
# KloutScore               50
# Name: 323.0, dtype: object
# Username1     alyssajordaan
# Username2       DomConnelly
# KloutScore               38
# Name: 324.0, dtype: object
# Username1       raychcoonz
# Username2     ashleighone3
# KloutScore              35
# Name: 325.0, dtype: object
# Username1          ItsBeccks
# Username2     timmyselfridge
# KloutScore                39
# Name: 326.0, dtype: object
# Username1           Prime_FR
# Username2     Sandy_cheeeeks
# KloutScore                46
# Name: 327.0, dtype: object
# Username1     lilyharringtonn
# Username2          luke_wyman
# KloutScore                 44
# Name: 328.0, dtype: object
# Username1     carolinaCRUNCH
# Username2            plazaj3
# KloutScore                38
# Name: 329.0, dtype: object
# Username1     erin_gallo12
# Username2     erin_gallo12
# KloutScore              41
# Name: 332.0, dtype: object
# Username1     nicolemartignet
# Username2          kellycsogi
# KloutScore                 44
# Name: 333.0, dtype: object
# Username1         davidnin_
# Username2     christian_nin
# KloutScore               33
# Name: 334.0, dtype: object
# Username1     bananaafish
# Username2     bananaafish
# KloutScore             56
# Name: 335.0, dtype: object
# Username1     ImAdelia_kThnks
# Username2      therealbrrando
# KloutScore                 36
# Name: 336.0, dtype: object
# Username1      Lugadu75
# Username2     chersan00
# KloutScore           36
# Name: 339.0, dtype: object
# Username1     capemayblogger
# Username2       CapeMayPoint
# KloutScore                40
# Name: 340.0, dtype: object
# Username1     AngAlmeida92
# Username2       xoamber0ox
# KloutScore              26
# Name: 341.0, dtype: object
# Username1         TheRealEhqo
# Username2     victorialoves11
# KloutScore                 23
# Name: 342.0, dtype: object
# Username1     BallTil_IDie_LC
# Username2          MarkChainz
# KloutScore                 40
# Name: 343.0, dtype: object
# Username1       the_funkkk
# Username2     davehalikman
# KloutScore              41
# Name: 349.0, dtype: object
# Username1     MaGzZz9
# Username2      GCoss5
# KloutScore         42
# Name: 351.0, dtype: object
# Username1     SlimeTimeLive_
# Username2     SlimeTimeLive_
# KloutScore                37
# Name: 352.0, dtype: object
# Username1       nick9shirey
# Username2     ChadAnthony12
# KloutScore               32
# Name: 353.0, dtype: object
# Username1       M2MEee
# Username2     redeader
# KloutScore          49
# Name: 354.0, dtype: object
# Username1     xKeylaDuarte
# Username2         ImToFake
# KloutScore              38
# Name: 355.0, dtype: object
# Username1     MollieHurley
# Username2        AirGibson
# KloutScore              41
# Name: 356.0, dtype: object
# Username1     YoungLeek_609
# Username2     Caramel_Keash
# KloutScore               41
# Name: 359.0, dtype: object
# Username1        _ndcv
# Username2     heyjuicy
# KloutScore          44
# Name: 362.0, dtype: object
# Username1     jakotrotter
# Username2     jakotrotter
# KloutScore             27
# Name: 363.0, dtype: object
# Username1     insanevrs7410
# Username2     insanevrs7410
# KloutScore               11
# Name: 370.0, dtype: object
# Username1     DAVIDX0828
# Username2     DAVIDX0828
# KloutScore            30
# Name: 371.0, dtype: object
# Username1     SteffEsposito
# Username2        FreddyJ_23
# KloutScore               42
# Name: 372.0, dtype: object
# Username1     chrisstineey
# Username2         livyyyx0
# KloutScore              37
# Name: 373.0, dtype: object
# Username1     LegendaryLuna
# Username2     DropX_Xgorjus
# KloutScore               39
# Name: 374.0, dtype: object
# Username1     hirsch_whathapp
# Username2           saruuusia
# KloutScore                 30
# Name: 375.0, dtype: object
# Username1     JonLeite
# Username2      xmfernx
# KloutScore          45
# Name: 377.0, dtype: object
# Username1     marcos1980nj
# Username2     marcos1980nj
# KloutScore              23
# Name: 381.0, dtype: object
# Username1      Kayleeee28
# Username2     bellllababy
# KloutScore             35
# Name: 382.0, dtype: object
# Username1     NickyStickzzz
# Username2     NickyStickzzz
# KloutScore               34
# Name: 388.0, dtype: object
# Username1     TravelMole
# Username2     TravelMole
# KloutScore            59
# Name: 389.0, dtype: object
# Username1     Hyannis02601
# Username2     Hyannis02601
# KloutScore              40
# Name: 395.0, dtype: object
# Username1     natjonesz
# Username2     natjonesz
# KloutScore           38
# Name: 399.0, dtype: object
# Username1     MikeOrtiz17
# Username2     MikeOrtiz17
# KloutScore             43
# Name: 400.0, dtype: object
# Username1     BuileDeargTGN
# Username2         rosamundd
# KloutScore               44
# Name: 401.0, dtype: object
# Username1     Georgia46502125
# Username2       IvoryNRoberts
# KloutScore                 33
# Name: 402.0, dtype: object
# Username1       xFINGERPOINTx
# Username2     paytonismissing
# KloutScore                 37
# Name: 403.0, dtype: object
# Username1     carlamarleny
# Username2        Juanito13
# KloutScore              31
# Name: 404.0, dtype: object
# Username1        amberscott07
# Username2     briannnaa_lynnn
# KloutScore                 36
# Name: 405.0, dtype: object
# Username1       _ToRealMeer
# Username2     ImThe_ShitHoe
# KloutScore               50
# Name: 407.0, dtype: object
# Username1     ggrasso1962
# Username2     ggrasso1962
# KloutScore             10
# Name: 408.0, dtype: object
# Username1     Hoe_ILoveMoney
# Username2        kyha_Miayhn
# KloutScore                35
# Name: 409.0, dtype: object
# Username1     DavidWilzJr
# Username2        esulek80
# KloutScore             26
# Name: 410.0, dtype: object
# Username1     jenmurph3
# Username2      a_masone
# KloutScore           32
# Name: 411.0, dtype: object
# Username1     beckam_
# Username2     beckam_
# KloutScore         41
# Name: 415.0, dtype: object
# Username1     kimmc1117
# Username2     kimmc1117
# KloutScore           14
# Name: 416.0, dtype: object
# Username1     unichicago
# Username2     unichicago
# KloutScore            54
# Name: 418.0, dtype: object
# Username1      jcrayze
# Username2     MintoInc
# KloutScore          22
# Name: 421.0, dtype: object
# Username1        antiigonahh
# Username2     albulenaBalena
# KloutScore                44
# Name: 422.0, dtype: object
# Username1      Hurley4me
# Username2     luckykid79
# KloutScore            43
# Name: 423.0, dtype: object
# Username1     MAD_ee_O
# Username2     MAD_ee_O
# KloutScore          29
# Name: 425.0, dtype: object
# Username1     Jarred_Diorio
# Username2      JaredMello33
# KloutScore               42
# Name: 428.0, dtype: object
# Username1         lindsaayym
# Username2     valeryximenaa_
# KloutScore                40
# Name: 429.0, dtype: object
# Username1     EricDargisInc
# Username2        nickymahns
# KloutScore               44
# Name: 430.0, dtype: object
# Username1     Katiiemartin
# Username2       Jbro0o0oks
# KloutScore              38
# Name: 432.0, dtype: object
# Username1     karissavelez
# Username2      bettycasey1
# KloutScore              45
# Name: 435.0, dtype: object
# Username1     UptownBrizzown
# Username2     UptownBrizzown
# KloutScore                45
# Name: 436.0, dtype: object
# Username1           EzBlazin
# Username2     matthewlondono
# KloutScore                37
# Name: 437.0, dtype: object
# Username1         megstaaaa
# Username2     jillianohdamn
# KloutScore               40
# Name: 440.0, dtype: object
# Username1        Vveto
# Username2     kwab3na7
# KloutScore          35
# Name: 443.0, dtype: object
# Username1     NICKaPHENOM
# Username2        L_PapS42
# KloutScore             35
# Name: 444.0, dtype: object
# Username1          Malikk193
# Username2     TakemeasiamXo3
# KloutScore                30
# Name: 445.0, dtype: object
# Username1     renatatraverso
# Username2        KaseyBrochu
# KloutScore                46
# Name: 448.0, dtype: object
# Username1     CaLynnCal
# Username2     CaLynnCal
# KloutScore           22
# Name: 450.0, dtype: object
# Username1     LainezKA
# Username2     LainezKA
# KloutScore          37
# Name: 452.0, dtype: object
# Username1        krysbabyxo
# Username2     VickNalentino
# KloutScore               42
# Name: 453.0, dtype: object
# Username1     nicolelmancini
# Username2        livinbreezy
# KloutScore                41
# Name: 454.0, dtype: object
# Username1     dylan_woodruff
# Username2      h0llynaclerio
# KloutScore                34
# Name: 455.0, dtype: object
# Username1             Jsine35
# Username2     amontecalvo_515
# KloutScore                 29
# Name: 457.0, dtype: object
# Username1            plazaj3
# Username2     carolinaCRUNCH
# KloutScore                39
# Name: 458.0, dtype: object
# Username1        Holla_Devin
# Username2     LlyssaLove1020
# KloutScore                28
# Name: 459.0, dtype: object
# Username1     Nikelii
# Username2     Nikelii
# KloutScore         45
# Name: 463.0, dtype: object
# Username1     Asavocchi21
# Username2     mattbedross
# KloutScore             43
# Name: 464.0, dtype: object
# Username1     ericaleighfred
# Username2        alexabranco
# KloutScore                43
# Name: 465.0, dtype: object
# Username1         imReckless_
# Username2     PabloBleedBlue3
# KloutScore                 42
# Name: 466.0, dtype: object
# Username1     April_Sigoda
# Username2     amandaamae02
# KloutScore              33
# Name: 468.0, dtype: object
# Username1     Tshoultes23
# Username2     Tshoultes23
# KloutScore             37
# Name: 470.0, dtype: object
# Username1        Qaadi_Stoner
# Username2     feelLYNN_myself
# KloutScore                 38
# Name: 471.0, dtype: object
# Username1     A_THRiLL34
# Username2     stephpalka
# KloutScore            35
# Name: 473.0, dtype: object
# Username1      MatthewTaylorr
# Username2     ErikaaPettersen
# KloutScore                 41
# Name: 474.0, dtype: object
# Username1     g0osemahh
# Username2     g0osemahh
# KloutScore           30
# Name: 475.0, dtype: object
# Username1      yO_cOriO
# Username2     cdamato23
# KloutScore           37
# Name: 476.0, dtype: object
# Username1     maceykateee
# Username2     maceykateee
# KloutScore             44
# Name: 477.0, dtype: object
# Username1             saigee3
# Username2     spartadiamond10
# KloutScore                 30
# Name: 478.0, dtype: object
# Username1     Jasssminnn_
# Username2         DJposts
# KloutScore             43
# Name: 479.0, dtype: object
# Username1     bellllababy
# Username2      Kayleeee28
# KloutScore             35
# Name: 480.0, dtype: object
# Username1     GishAllday
# Username2     GishAllday
# KloutScore            30
# Name: 483.0, dtype: object
# Username1     AtriumNYC
# Username2     AtriumNYC
# KloutScore           62
# Name: 491.0, dtype: object
# Username1     Aliciafbabyy24
# Username2     PiresDGAF_xoxo
# KloutScore                31
# Name: 492.0, dtype: object
# Username1     kristeninglesby
# Username2     nickie_inglesby
# KloutScore                 43
# Name: 493.0, dtype: object
# Username1     metro_man
# Username2        Amtrak
# KloutScore           90
# Name: 494.0, dtype: object
# Username1     luckykid79
# Username2      Hurley4me
# KloutScore            46
# Name: 495.0, dtype: object
# Username1      Jushunter10
# Username2     _AaronRenaud
# KloutScore              45
# Name: 496.0, dtype: object
# Username1     chronicleherald
# Username2     chronicleherald
# KloutScore                 65
# Name: 498.0, dtype: object
# Username1     BELSMS
# Username2     BELSMS
# KloutScore        35
# Name: 499.0, dtype: object
# Username1     briannaL_
# Username2     IHeart_DR
# KloutScore           42
# Name: 500.0, dtype: object
# Username1     nada_itti
# Username2     nada_itti
# KloutScore           27
# Name: 502.0, dtype: object
# Username1     HowSobelOfYou
# Username2     HowSobelOfYou
# KloutScore               41
# Name: 503.0, dtype: object
# Username1     LijahTheProfit
# Username2     LijahTheProfit
# KloutScore                41
# Name: 504.0, dtype: object
# Username1     lauraabritton
# Username2          KBuroojy
# KloutScore               28
# Name: 506.0, dtype: object
# Username1     PhilipRector
# Username2        CBroyles3
# KloutScore              43
# Name: 511.0, dtype: object
# Username1         Jeffkurk
# Username2     marlatheboss
# KloutScore              37
# Name: 513.0, dtype: object
# Username1     swagcostanso
# Username2     swagcostanso
# KloutScore              41
# Name: 514.0, dtype: object
# Username1     kr3at
# Username2     kr3at
# KloutScore       65
# Name: 515.0, dtype: object
# Username1     fusc0fr3sh
# Username2     fusc0fr3sh
# KloutScore            36
# Name: 516.0, dtype: object
# Username1           saruuusia
# Username2     hirsch_whathapp
# KloutScore                 44
# Name: 517.0, dtype: object
# Username1     SmileBack95
# Username2     SmileBack95
# KloutScore             44
# Name: 518.0, dtype: object
# Username1     sara_cosseboom
# Username2         lace_a_lee
# KloutScore                28
# Name: 519.0, dtype: object
# Username1     DjMattyGNJ
# Username2     DjMattyGNJ
# KloutScore            18
# Name: 521.0, dtype: object
# Username1     classic_chick1
# Username2          Paigevic5
# KloutScore                48
# Name: 522.0, dtype: object
# Username1     Ants_SNEweather
# Username2         Firehound55
# KloutScore                 39
# Name: 529.0, dtype: object
# Username1     caroline_cote
# Username2     caroline_cote
# KloutScore               43
# Name: 532.0, dtype: object
# Username1     joelfreak
# Username2         exiva
# KloutScore           48
# Name: 534.0, dtype: object
# Username1     ForrestEdson
# Username2     ForrestEdson
# KloutScore              34
# Name: 535.0, dtype: object
# Username1     melissLx0
# Username2     briannaL_
# KloutScore           40
# Name: 536.0, dtype: object
# Username1     HATCHETTES
# Username2     HATCHETTES
# KloutScore            48
# Name: 538.0, dtype: object
# Username1     SierraAdetula
# Username2     SierraAdetula
# KloutScore               38
# Name: 539.0, dtype: object
# Username1     mnkeydo
# Username2     mnkeydo
# KloutScore         19
# Name: 540.0, dtype: object
# Username1     LDNews
# Username2     LDNews
# KloutScore        52
# Name: 541.0, dtype: object
# Username1     Rock365Radio
# Username2     Rock365Radio
# KloutScore              60
# Name: 542.0, dtype: object
# Username1     monteirozinha
# Username2     monteirozinha
# KloutScore               29
# Name: 543.0, dtype: object
# Username1     seanneilbarron
# Username2     seanneilbarron
# KloutScore                29
# Name: 544.0, dtype: object
# Username1     laurencaseyyy
# Username2     sophiecasey86
# KloutScore               32
# Name: 545.0, dtype: object
# Username1     ThaReal_Streetz
# Username2     ThaReal_Streetz
# KloutScore                 41
# Name: 546.0, dtype: object
# Username1     PWAPN
# Username2     PWAPN
# KloutScore       50
# Name: 547.0, dtype: object
# Username1     AnaVictoriaxoxo
# Username2           TPilovsky
# KloutScore                 37
# Name: 548.0, dtype: object
# Username1     wnep
# Username2     wnep
# KloutScore      59
# Name: 550.0, dtype: object
# Username1     KaylaPreviti
# Username2     KaylaPreviti
# KloutScore              35
# Name: 551.0, dtype: object
# Username1     BrassTitanic
# Username2     BrassTitanic
# KloutScore              56
# Name: 552.0, dtype: object
# Username1     ryankentm
# Username2     smitty262
# KloutScore           28
# Name: 555.0, dtype: object
# Username1      Cait_Fox
# Username2     lalaleela
# KloutScore           49
# Name: 557.0, dtype: object
# Username1         senaefe
# Username2     eceesirtgen
# KloutScore             31
# Name: 558.0, dtype: object
# Username1       ElyseLol
# Username2     Tuccisback
# KloutScore            46
# Name: 564.0, dtype: object
# Username1     jessicabureau
# Username2      TheRealPecor
# KloutScore               42
# Name: 567.0, dtype: object
# Username1     jescobar9513
# Username2       j_galindoo
# KloutScore              35
# Name: 569.0, dtype: object
# Username1       KimHarvz
# Username2     kellytiki3
# KloutScore            35
# Name: 571.0, dtype: object
# Username1     _NicoleGriffith
# Username2     _NicoleGriffith
# KloutScore                 34
# Name: 572.0, dtype: object
# Username1      SamCantReed
# Username2     Jason_Bosket
# KloutScore              26
# Name: 573.0, dtype: object
# Username1     silverbulletzx3
# Username2      Madgrandmatobe
# KloutScore                 53
# Name: 577.0, dtype: object
# Username1        SoapNSoda
# Username2     KatrinaaElly
# KloutScore              46
# Name: 578.0, dtype: object
# Username1        L_PapS42
# Username2     NICKaPHENOM
# KloutScore             37
# Name: 579.0, dtype: object
# Username1     AJDJProductions
# Username2     AJDJProductions
# KloutScore                 33
# Name: 581.0, dtype: object
# Username1     VinnyLatorraca
# Username2      SeanPKennedy2
# KloutScore                42
# Name: 585.0, dtype: object
# Username1      Honduras_Jay21
# Username2     vivalacaitybaby
# KloutScore                 42
# Name: 586.0, dtype: object
# Username1     GoodDayOregon
# Username2     GoodDayOregon
# KloutScore               45
# Name: 587.0, dtype: object
# Username1     DjCrysis_
# Username2     djbstylzz
# KloutScore           47
# Name: 588.0, dtype: object
# Username1     _CirocBoyy
# Username2     _CirocBoyy
# KloutScore            37
# Name: 589.0, dtype: object
# Username1     tayanichole
# Username2     BombAssAsia
# KloutScore             50
# Name: 590.0, dtype: object
# Username1       IM_OUT_HERE
# Username2     DomTurn_Heads
# KloutScore               52
# Name: 592.0, dtype: object
# Username1     dr_jay23
# Username2     dr_jay23
# KloutScore          27
# Name: 593.0, dtype: object
# Username1     amandaamae02
# Username2     April_Sigoda
# KloutScore              43
# Name: 594.0, dtype: object
# Username1      therealbrrando
# Username2     ImAdelia_kThnks
# KloutScore                 35
# Name: 596.0, dtype: object
# Username1       IvoryNRoberts
# Username2     Georgia46502125
# KloutScore                 39
# Name: 598.0, dtype: object
# Username1       LadyBugCharee
# Username2     victoriaarachel
# KloutScore                 39
# Name: 599.0, dtype: object
# Username1        Markieton97
# Username2     DeanetteAcosta
# KloutScore                33
# Name: 600.0, dtype: object
# Username1     chloextaylorr
# Username2        TJFBball25
# KloutScore               42
# Name: 603.0, dtype: object
# Username1     albulenaBalena
# Username2        antiigonahh
# KloutScore                46
# Name: 604.0, dtype: object
# Username1        Amtrak
# Username2     metro_man
# KloutScore           52
# Name: 605.0, dtype: object
# Username1     heyjuicy
# Username2        _ndcv
# KloutScore          53
# Name: 607.0, dtype: object
# Username1     Celso_Limousine
# Username2     Celso_Limousine
# KloutScore                 18
# Name: 608.0, dtype: object
# Username1     MrRickySauces
# Username2       alyssapatti
# KloutScore               42
# Name: 609.0, dtype: object
# Username1     _illuminare
# Username2        frostyLQ
# KloutScore             39
# Name: 611.0, dtype: object
# Username1     soulartistic_
# Username2        xocorinaxo
# KloutScore               54
# Name: 615.0, dtype: object
# Username1        wllbotfMCRmf
# Username2     NoFucksGiven_14
# KloutScore                 35
# Name: 621.0, dtype: object
# Username1        AirGibson
# Username2     MollieHurley
# KloutScore              42
# Name: 622.0, dtype: object
# Username1     StarGang_617
# Username2        meilynx33
# KloutScore              34
# Name: 623.0, dtype: object
# Username1     ktolomeo14
# Username2     ktolomeo14
# KloutScore            33
# Name: 624.0, dtype: object
# Username1     ItsBRI_CuzImHot
# Username2     CharlieSoBoojie
# KloutScore                 46
# Name: 625.0, dtype: object
# Username1     ImThe_ShitHoe
# Username2       _ToRealMeer
# KloutScore               50
# Name: 626.0, dtype: object
# Username1      MattlyWCCC
# Username2     LBrownholtz
# KloutScore             40
# Name: 627.0, dtype: object
# Username1     Gnarly_Marlee
# Username2         LeeuhBfab
# KloutScore               44
# Name: 632.0, dtype: object
# Username1     highland_grille
# Username2     highland_grille
# KloutScore                 21
# Name: 633.0, dtype: object
# Username1     Jennyyxoxox
# Username2     g_ramirez13
# KloutScore             44
# Name: 634.0, dtype: object
# Username1      unichron420
# Username2     lizdollabill
# KloutScore              44
# Name: 644.0, dtype: object
# Username1     JCyPan
# Username2     JCyPan
# KloutScore         0
# Name: 645.0, dtype: object
# Username1      hannah_beauton
# Username2     JordynTayNatale
# KloutScore                 35
# Name: 647.0, dtype: object
# Username1        Juanito13
# Username2     carlamarleny
# KloutScore              43
# Name: 648.0, dtype: object
# Username1     cordae18kordil
# Username2     cordae18kordil
# KloutScore                 0
# Name: 649.0, dtype: object
# Username1     AnthonyMOliva
# Username2     AnthonyMOliva
# KloutScore               42
# Name: 652.0, dtype: object
# Username1     mama_ubu
# Username2     papa_ubu
# KloutScore          19
# Name: 653.0, dtype: object
# Username1      Joe_napo
# Username2     gabvalela
# KloutScore           42
# Name: 654.0, dtype: object
# Username1     cdamato23
# Username2      yO_cOriO
# KloutScore           42
# Name: 656.0, dtype: object
# Username1     briannaL_
# Username2     melissLx0
# KloutScore           40
# Name: 667.0, dtype: object
# Username1     2xist
# Username2     2xist
# KloutScore       29
# Name: 669.0, dtype: object
# Username1     TMekuli
# Username2     TMekuli
# KloutScore         45
# Name: 670.0, dtype: object
# Username1     AllPhaseCC
# Username2     AllPhaseCC
# KloutScore             0
# Name: 671.0, dtype: object
# Username1     JordynTayNatale
# Username2      hannah_beauton
# KloutScore                 36
# Name: 672.0, dtype: object
# Username1     kwab3na7
# Username2        Vveto
# KloutScore          41
# Name: 673.0, dtype: object
# Username1        Cwalks3
# Username2     TimmyD0415
# KloutScore            38
# Name: 674.0, dtype: object
# Username1     ejosec
# Username2     ejosec
# KloutScore        24
# Name: 675.0, dtype: object
# Username1         LeeuhBfab
# Username2     Gnarly_Marlee
# KloutScore               36
# Name: 676.0, dtype: object
# Username1     DaBoulNickyD
# Username2          ovega95
# KloutScore              45
# Name: 677.0, dtype: object
# Username1     4MRWILSON
# Username2     4MRWILSON
# KloutScore           21
# Name: 679.0, dtype: object
# Username1        jessdood
# Username2     _anchordown
# KloutScore             43
# Name: 680.0, dtype: object
# Username1     yourgirlshousee
# Username2                cbx0
# KloutScore                 19
# Name: 681.0, dtype: object
# Username1     Mr_Rivs15
# Username2     _ChelleyO
# KloutScore           39
# Name: 682.0, dtype: object
# Username1     TheeWarlock
# Username2     TheeWarlock
# KloutScore             40
# Name: 684.0, dtype: object
# Username1     snydaho
# Username2     snydaho
# KloutScore         41
# Name: 685.0, dtype: object
# Username1     abvanderziel
# Username2       amb_noelle
# KloutScore              31
# Name: 686.0, dtype: object
# Username1     papa_ubu
# Username2     mama_ubu
# KloutScore          28
# Name: 687.0, dtype: object
# Username1     alfonso_sanche
# Username2     alfonso_sanche
# KloutScore                16
# Name: 688.0, dtype: object
# Username1     AlekGerstenberg
# Username2          BradenKoch
# KloutScore                 39
# Name: 690.0, dtype: object
# Username1     MiSsChRiSsY011
# Username2               H4i5
# KloutScore                51
# Name: 691.0, dtype: object
# Username1      erinsheaaa
# Username2     becca_snell
# KloutScore             42
# Name: 692.0, dtype: object
# Username1              _Eshli
# Username2     ThurlAddiction_
# KloutScore                 37
# Name: 693.0, dtype: object
# Username1     LilRedCart
# Username2     LilRedCart
# KloutScore            13
# Name: 694.0, dtype: object
# Username1     Haystack_92
# Username2     Haystack_92
# KloutScore             42
# Name: 701.0, dtype: object
# Username1     IHeart_DR
# Username2     briannaL_
# KloutScore           40
# Name: 702.0, dtype: object
# Username1     delbenz
# Username2     delbenz
# KloutScore         45
# Name: 703.0, dtype: object
# Username1      _mariadeleon
# Username2     _eileendennis
# KloutScore               43
# Name: 705.0, dtype: object
# Username1     PCSTcomics
# Username2     PCSTcomics
# KloutScore            21
# Name: 707.0, dtype: object
# Username1      ahlexieah
# Username2     GigiCutie_
# KloutScore            43
# Name: 708.0, dtype: object
# Username1     nicoleflankkk
# Username2       RayEllisIII
# KloutScore               47
# Name: 709.0, dtype: object
# Username1     lizdollabill
# Username2      unichron420
# KloutScore              55
# Name: 712.0, dtype: object
# Username1     Gotta_Jimmy
# Username2     Gotta_Jimmy
# KloutScore             44
# Name: 726.0, dtype: object
# Username1     victorialoves11
# Username2         TheRealEhqo
# KloutScore                 41
# Name: 729.0, dtype: object
# Username1     Cox7498
# Username2     Cox7498
# KloutScore          0
# Name: 730.0, dtype: object
# Username1         _KingIke
# Username2     _atothemanda
# KloutScore              41
# Name: 731.0, dtype: object
# Username1     Tuccisback
# Username2       ElyseLol
# KloutScore            46
# Name: 732.0, dtype: object
# Username1          j0hnj0
# Username2     elcheguis19
# KloutScore             43
# Name: 742.0, dtype: object
# Username1     FrenchInhala
# Username2     FrenchInhala
# KloutScore              35
# Name: 745.0, dtype: object
# Username1      GCoss5
# Username2     MaGzZz9
# KloutScore         41
# Name: 746.0, dtype: object
# Username1     breathaLIZA
# Username2     RyanNorvish
# KloutScore             42
# Name: 748.0, dtype: object
# Username1     rmrconsultant
# Username2     rmrconsultant
# KloutScore               19
# Name: 749.0, dtype: object
# Username1            yofuff
# Username2     londrizzzzzle
# KloutScore               41
# Name: 750.0, dtype: object
# Username1     patricktrack
# Username2          ewood02
# KloutScore              45
# Name: 751.0, dtype: object
# Username1     sophiecasey86
# Username2     laurencaseyyy
# KloutScore               34
# Name: 752.0, dtype: object
# Username1         ohitsbobby
# Username2     ireneeeisGREEK
# KloutScore                46
# Name: 753.0, dtype: object
# Username1          TheNuGirl
# Username2     KyrieEleison24
# KloutScore                48
# Name: 754.0, dtype: object
# Username1     alisongracew
# Username2       KatyAlpino
# KloutScore              34
# Name: 759.0, dtype: object
# Username1       xoamber0ox
# Username2     AngAlmeida92
# KloutScore              39
# Name: 760.0, dtype: object
# Username1     saraadavis_
# Username2     bridamico99
# KloutScore             42
# Name: 761.0, dtype: object
# Username1       amb_noelle
# Username2     abvanderziel
# KloutScore              40
# Name: 765.0, dtype: object
# Username1     BetsySharpe3
# Username2     BetsySharpe3
# KloutScore              19
# Name: 770.0, dtype: object
# Username1       JackBessot
# Username2     Gautier_Jonc
# KloutScore              32
# Name: 771.0, dtype: object
# Username1     BrklynMoto
# Username2     BrklynMoto
# KloutScore            30
# Name: 772.0, dtype: object
# Username1         GTheBandit
# Username2     DonMagicDraper
# KloutScore                56
# Name: 773.0, dtype: object
# Username1     maryskribz
# Username2      tomconl3y
# KloutScore            42
# Name: 776.0, dtype: object
# Username1     captainSALUTE
# Username2      Miss_Kay_Lee
# KloutScore               49
# Name: 777.0, dtype: object
# Username1     thepadcaster
# Username2     thepadcaster
# KloutScore              29
# Name: 779.0, dtype: object
# Username1     ishiekush
# Username2      ChiqBmad
# KloutScore           42
# Name: 780.0, dtype: object
# Username1      BeazerNYJ
# Username2     AliTabasco
# KloutScore            48
# Name: 781.0, dtype: object
# Username1     LUIS_CASTRO_NYC
# Username2           nygeneral
# KloutScore                 47
# Name: 782.0, dtype: object
# Username1          jvargas108
# Username2     Nikita_Penelope
# KloutScore                 36
# Name: 784.0, dtype: object
# Username1      tomconl3y
# Username2     maryskribz
# KloutScore            34
# Name: 793.0, dtype: object
# Username1     lsbk1988
# Username2     lsbk1988
# KloutScore          13
# Name: 794.0, dtype: object
# Username1     annieb165
# Username2     annieb165
# KloutScore           46
# Name: 795.0, dtype: object
# Username1       Stunna_TheDj
# ...
# Username2     Delmax01
# KloutScore          17
# Name: 1340.0, dtype: object
# Username1      emi_xoxo_
# Username2     Bloodykidb
# KloutScore            29
# Name: 1351.0, dtype: object
# Username1          KMacD7
# Username2     jacobrflagg
# KloutScore             25
# Name: 1352.0, dtype: object
# Username1     r_lomba
# Username2     r_lomba
# KloutScore         31
# Name: 1353.0, dtype: object
# Username1     _AwesomeLyrics1
# Username2     _AwesomeLyrics1
# KloutScore                  0
# Name: 1354.0, dtype: object
# Username1     jerilynnturenne
# Username2     jerilynnturenne
# KloutScore                 30
# Name: 1355.0, dtype: object
# Username1     julieziGZAGz
# Username2     Farley_OVOXO
# KloutScore              36
# Name: 1356.0, dtype: object
# Username1     ACISpecBenefits
# Username2     ACISpecBenefits
# KloutScore                 41
# Name: 1357.0, dtype: object
# Username1     obviousamerica
# Username2     obviousamerica
# KloutScore                44
# Name: 1358.0, dtype: object
# Username1       Aadams90
# Username2     BruceJVail
# KloutScore            43
# Name: 1362.0, dtype: object
# Username1     gingatheninjaa
# Username2     gingatheninjaa
# KloutScore                43
# Name: 1363.0, dtype: object
# Username1     antsoto1108
# Username2     antsoto1108
# KloutScore             40
# Name: 1366.0, dtype: object
# Username1     joeyowen23
# Username2         RbreyS
# KloutScore            44
# Name: 1367.0, dtype: object
# Username1     McluvinEmily
# Username2      sam_lundyyy
# KloutScore              29
# Name: 1371.0, dtype: object
# Username1     AY0ASHTRAY
# Username2        cmrnchn
# KloutScore            42
# Name: 1372.0, dtype: object
# Username1       22lflores
# Username2     kissthisxoo
# KloutScore             43
# Name: 1373.0, dtype: object
# Username1     imadfarhod
# Username2     imadfarhod
# KloutScore            16
# Name: 1375.0, dtype: object
# Username1     allybabycakes
# Username2       xlauragrac3
# KloutScore               40
# Name: 1377.0, dtype: object
# Username1     EatMy_Couturee
# Username2     EatMy_Couturee
# KloutScore                45
# Name: 1378.0, dtype: object
# Username1     mkwrose
# Username2     mkwrose
# KloutScore         10
# Name: 1379.0, dtype: object
# Username1     closet_freaks
# Username2     closet_freaks
# KloutScore               62
# Name: 1380.0, dtype: object
# Username1     jamiesuzannex
# Username2         Taahir517
# KloutScore               45
# Name: 1381.0, dtype: object
# Username1       DomConnelly
# Username2     alyssajordaan
# KloutScore               46
# Name: 1384.0, dtype: object
# Username1     darlannennalrad
# Username2     jennnastfrancis
# KloutScore                 38
# Name: 1385.0, dtype: object
# Username1     KeshnaThermitus
# Username2     KeshnaThermitus
# KloutScore                 28
# Name: 1386.0, dtype: object
# Username1     redeader
# Username2       M2MEee
# KloutScore          45
# Name: 1387.0, dtype: object
# Username1     FashionableHost
# Username2     FashionableHost
# KloutScore                 34
# Name: 1388.0, dtype: object
# Username1     kissthisxoo
# Username2       22lflores
# KloutScore             39
# Name: 1397.0, dtype: object
# Username1         alehouse76
# Username2     emilygracepenn
# KloutScore                23
# Name: 1398.0, dtype: object
# Username1     cdros
# Username2     cdros
# KloutScore       14
# Name: 1399.0, dtype: object
# Username1     illmatic_TJ
# Username2      RaineeMaee
# KloutScore             42
# Name: 1400.0, dtype: object
# Username1          bigjoe_95
# Username2     dizzaylizzayyy
# KloutScore                35
# Name: 1401.0, dtype: object
# Username1     bigE1209
# Username2     toshiman
# KloutScore          40
# Name: 1402.0, dtype: object
# Username1     michelleeeann
# Username2     michelleeeann
# KloutScore               15
# Name: 1403.0, dtype: object
# Username1     TheBOMBshellll
# Username2           _umASIAN
# KloutScore                38
# Name: 1404.0, dtype: object
# Username1     ChefKelvin
# Username2     ChefKelvin
# KloutScore            48
# Name: 1406.0, dtype: object
# Username1     Scott_In_Worc
# Username2      GinsburgJobs
# KloutScore               59
# Name: 1410.0, dtype: object
# Username1     TERRYSMANE
# Username2     TERRYSMANE
# KloutScore            38
# Name: 1411.0, dtype: object
# Username1     javazquez4
# Username2     javazquez4
# KloutScore            11
# Name: 1412.0, dtype: object
# Username1     aliciamariexo21
# Username2          BangsWitMe
# KloutScore                 51
# Name: 1421.0, dtype: object
# Username1     jackie_is_cray
# Username2     jackie_is_cray
# KloutScore                31
# Name: 1422.0, dtype: object
# Username1       mkurkowski
# Username2     BostonBrodes
# KloutScore              60
# Name: 1423.0, dtype: object
# Username1     NickkBrookss
# Username2        I_AM_BAMA
# KloutScore              38
# Name: 1424.0, dtype: object
# Username1     jenmurph3
# Username2     jenmurph3
# KloutScore           38
# Name: 1425.0, dtype: object
# Username1        delbenz
# Username2     BobbyCz123
# KloutScore            26
# Name: 1430.0, dtype: object
# Username1          danagabor
# Username2     danaelizabitch
# KloutScore                43
# Name: 1431.0, dtype: object
# Username1         RbreyS
# Username2     joeyowen23
# KloutScore            37
# Name: 1434.0, dtype: object
# Username1     KyrieEleison24
# Username2          TheNuGirl
# KloutScore                45
# Name: 1444.0, dtype: object
# Username1     MikeyWhite11
# Username2       kevinberno
# KloutScore              42
# Name: 1447.0, dtype: object
# Username1     briannnaa_lynnn
# Username2        amberscott07
# KloutScore                 30
# Name: 1450.0, dtype: object
# Username1          BradenKoch
# Username2     AlekGerstenberg
# KloutScore                 43
# Name: 1455.0, dtype: object
# Username1     exit0jazzfest
# Username2     exit0jazzfest
# KloutScore               45
# Name: 1458.0, dtype: object
# Username1     Marii_Cona
# Username2     Marii_Cona
# KloutScore            42
# Name: 1460.0, dtype: object
# Username1     tinaxx77
# Username2     tinaxx77
# KloutScore          43
# Name: 1461.0, dtype: object
# Username1       kelshassay
# Username2     Briianadoyle
# KloutScore              35
# Name: 1462.0, dtype: object
# Username1     aluther80
# Username2     aluther80
# KloutScore           36
# Name: 1463.0, dtype: object
# Username1     BruceJVail
# Username2       Aadams90
# KloutScore            49
# Name: 1464.0, dtype: object
# Username1     amber_lavigne
# Username2     amber_lavigne
# KloutScore               38
# Name: 1465.0, dtype: object
# Username1     pistol_patches
# Username2            erinfur
# KloutScore                36
# Name: 1466.0, dtype: object
# Username1     twptweets
# Username2     twptweets
# KloutScore           42
# Name: 1468.0, dtype: object
# Username1     leventyuks3l
# Username2         Chhhloex
# KloutScore              45
# Name: 1469.0, dtype: object
# Username1                cbx0
# Username2     yourgirlshousee
# KloutScore                 40
# Name: 1470.0, dtype: object
# Username1     iNameManda
# Username2     iNameManda
# KloutScore            32
# Name: 1471.0, dtype: object
# Username1     cleevycleeve
# Username2       binkastram
# KloutScore              30
# Name: 1472.0, dtype: object
# Username1       Wild_Onex3
# Username2     iMechanicJDM
# KloutScore              39
# Name: 1473.0, dtype: object
# Username1       kailyndill
# Username2     kaylablakely
# KloutScore              37
# Name: 1476.0, dtype: object
# Username1     RyanNorvish
# Username2     breathaLIZA
# KloutScore             43
# Name: 1477.0, dtype: object
# Username1     1459Reid
# Username2     1459Reid
# KloutScore           0
# Name: 1481.0, dtype: object
# Username1     Starrkisses_
# Username2         vante_12
# KloutScore              38
# Name: 1483.0, dtype: object
# Username1     Jayb725L
# Username2     Jayb725L
# KloutScore          40
# Name: 1485.0, dtype: object
# Username1     TimmyD0415
# Username2        Cwalks3
# KloutScore            37
# Name: 1486.0, dtype: object
# Username1     smitty262
# Username2     ryankentm
# KloutScore           50
# Name: 1487.0, dtype: object
# Username1     MarcelinDchmps
# Username2     MarcelinDchmps
# KloutScore                56
# Name: 1488.0, dtype: object
# Username1     gregwimbish
# Username2     gregwimbish
# KloutScore             13
# Name: 1489.0, dtype: object
# Username1     Landsharkkong64
# Username2     Landsharkkong64
# KloutScore                 41
# Name: 1490.0, dtype: object
# Username1       Kendaalllx3
# Username2     cassandraxoxx
# KloutScore               33
# Name: 1491.0, dtype: object
# Username1     ErikaaPettersen
# Username2      MatthewTaylorr
# KloutScore                 43
# Name: 1494.0, dtype: object
# Username1     dabal_aj
# Username2     dabal_aj
# KloutScore          43
# Name: 1497.0, dtype: object
# Username1     thisdorkjessica
# Username2     Dont_JudgeChris
# KloutScore                 41
# Name: 1498.0, dtype: object
# Username1     _anchordown
# Username2        jessdood
# KloutScore             39
# Name: 1499.0, dtype: object
# Username1        cmrnchn
# Username2     AY0ASHTRAY
# KloutScore            41
# Name: 1501.0, dtype: object
# Username1     bmirandaa
# Username2     bmirandaa
# KloutScore           42
# Name: 1503.0, dtype: object
# Username1     Lewismrobbs
# Username2     Lewismrobbs
# KloutScore             21
# Name: 1504.0, dtype: object
# Username1     ChadAnthony12
# Username2       nick9shirey
# KloutScore               38
# Name: 1505.0, dtype: object
# Username1     SierraAcevedo1
# Username2     SierraAcevedo1
# KloutScore                43
# Name: 1506.0, dtype: object
# Username1     kortney_renee
# Username2          GabieKur
# KloutScore               65
# Name: 1508.0, dtype: object
# Username1     Carlyyxox
# Username2     Carlyyxox
# KloutScore           38
# Name: 1509.0, dtype: object
# Username1     GinaAngellella
# Username2     GinaAngellella
# KloutScore                16
# Name: 1510.0, dtype: object
# Username1     yosupaaronheard
# Username2     helloiamamerica
# KloutScore                 47
# Name: 1511.0, dtype: object
# Username1      chrisssssteen
# Username2     curious_gorgee
# KloutScore                30
# Name: 1512.0, dtype: object
# Username1     ZgY1nR
# Username2     ZgY1nR
# KloutScore        18
# Name: 1513.0, dtype: object
# Username1        tylerdemuro
# Username2     SirJacobMorris
# KloutScore                42
# Name: 1518.0, dtype: object
# Username1     bettycasey1
# Username2      MegRyannnn
# KloutScore             36
# Name: 1520.0, dtype: object
# Username1     mizwunmie
# Username2     mizwunmie
# KloutScore           46
# Name: 1521.0, dtype: object
# Username1     AmkKampo
# Username2     AmkKampo
# KloutScore          12
# Name: 1522.0, dtype: object
# Username1        I_AM_BAMA
# Username2     NickkBrookss
# KloutScore              47
# Name: 1523.0, dtype: object
# Username1     DarielleRosario
# Username2             Makaa_L
# KloutScore                 44
# Name: 1525.0, dtype: object
# Username1     rodriguez1208
# Username2     rodriguez1208
# KloutScore               18
# Name: 1528.0, dtype: object
# Username1     Andylove509
# Username2     Andylove509
# KloutScore             31
# Name: 1529.0, dtype: object
# Username1     KLTV7
# Username2     KLTV7
# KloutScore       59
# Name: 1530.0, dtype: object
# Username1     ihsantarore
# Username2     rinimarwini
# KloutScore             42
# Name: 1531.0, dtype: object
# Username1     kellytiki3
# Username2       KimHarvz
# KloutScore            25
# Name: 1533.0, dtype: object
# Username1     poche28
# Username2     poche28
# KloutScore         38
# Name: 1540.0, dtype: object
# Username1        SamSchoepfer
# Username2     _maddieberrioxo
# KloutScore                 37
# Name: 1547.0, dtype: object
# Username1       CanCanMarie
# Username2     cassiex0ellis
# KloutScore               43
# Name: 1548.0, dtype: object
# Username1         Taahir517
# Username2     jamiesuzannex
# KloutScore               42
# Name: 1549.0, dtype: object
# Username1     danaelizabitch
# Username2          danagabor
# KloutScore                42
# Name: 1551.0, dtype: object
# Username1     joseridesbmx
# Username2       bmx24seven
# KloutScore              41
# Name: 1552.0, dtype: object
# Username1      sam_lundyyy
# Username2     McluvinEmily
# KloutScore              34
# Name: 1558.0, dtype: object
# Username1     MelissaMissy731
# Username2     MelissaMissy731
# KloutScore                 28
# Name: 1562.0, dtype: object
# Username1     Paddy_Crean
# Username2      BrittMlaka
# KloutScore             35
# Name: 1569.0, dtype: object
# Username1     ScottWilliamsTV
# Username2         FOX29philly
# KloutScore                 72
# Name: 1572.0, dtype: object
# Username1     paytonismissing
# Username2       xFINGERPOINTx
# KloutScore                 61
# Name: 1576.0, dtype: object
# Username1     canes4184
# Username2      bobalcus
# KloutScore           24
# Name: 1578.0, dtype: object
# Username1     __AcapulcoGold
# Username2      2Girls1Rickey
# KloutScore                39
# Name: 1584.0, dtype: object
# Username1     AKADaStallion
# Username2      BigShane1216
# KloutScore               26
# Name: 1585.0, dtype: object
# Username1     OhThatsDerek
# Username2       _weloveJay
# KloutScore              40
# Name: 1590.0, dtype: object
# Username1     SeanPhelan5
# Username2       SRdipalot
# KloutScore             36
# Name: 1591.0, dtype: object
# Username1     Dont_JudgeChris
# Username2     thisdorkjessica
# KloutScore                 40
# Name: 1594.0, dtype: object
# Username1     ToppingRose
# Username2     ToppingRose
# KloutScore             43
# Name: 1595.0, dtype: object
# Username1     Dr_ChrisMagboo
# Username2          giiidavis
# KloutScore                43
# Name: 1597.0, dtype: object
# Username1     CampingSurvival
# Username2     CampingSurvival
# KloutScore                 71
# Name: 1598.0, dtype: object
# Username1     KiaNYC
# Username2     KiaNYC
# KloutScore        36
# Name: 1599.0, dtype: object
# Username1     Farley_OVOXO
# Username2     julieziGZAGz
# KloutScore              35
# Name: 1600.0, dtype: object
# Username1     MrAnthonyRaul
# Username2     MrAnthonyRaul
# KloutScore               41
# Name: 1601.0, dtype: object
# Username1     WrestleCade
# Username2     WrestleCade
# KloutScore             52
# Name: 1602.0, dtype: object
# Username1         exiva
# Username2     joelfreak
# KloutScore           40
# Name: 1604.0, dtype: object
# Username1      meagfahey
# Username2     jfahey5856
# KloutScore            24
# Name: 1609.0, dtype: object
# Username1      2Girls1Rickey
# Username2     __AcapulcoGold
# KloutScore                40
# Name: 1610.0, dtype: object
# Username1     TifoshinRogers
# Username2     TifoshinRogers
# KloutScore                24
# Name: 1614.0, dtype: object
# Username1     DaBoulRash
# Username2     mo_abdul23
# KloutScore            39
# Name: 1622.0, dtype: object
# Username1     YoGoWild
# Username2     YoGoWild
# KloutScore          25
# Name: 1630.0, dtype: object
# Username1     londrizzzzzle
# Username2            yofuff
# KloutScore               37
# Name: 1632.0, dtype: object
# Username1     emilygracepenn
# Username2         alehouse76
# KloutScore                29
# Name: 1634.0, dtype: object
# Username1               H4i5
# Username2     MiSsChRiSsY011
# KloutScore                40
# Name: 1635.0, dtype: object
# Username1     pa_davis101
# Username2       WTFkrissy
# KloutScore             47
# Name: 1638.0, dtype: object
# Username1      a_masone
# Username2     jenmurph3
# KloutScore           38
# Name: 1648.0, dtype: object
# Username1     NakaseArt
# Username2     Kirbynite
# KloutScore           29
# Name: 1649.0, dtype: object
# Username1     SteveNati35
# Username2         bri_sco
# KloutScore             48
# Name: 1650.0, dtype: object
# Username1       _weloveJay
# Username2     OhThatsDerek
# KloutScore              44
# Name: 1652.0, dtype: object
# Username1     NiceGuyTeele91
# Username2     4ngelo5carfone
# KloutScore                45
# Name: 1653.0, dtype: object
# Username1     moll_foxx
# Username2       Cwalks3
# KloutScore           37
# Name: 1654.0, dtype: object
# Username1     BobbyCz123
# Username2        delbenz
# KloutScore            45
# Name: 1661.0, dtype: object
# Username1     RbRLiveStudio
# Username2     RbRLiveStudio
# KloutScore               43
# Name: 1662.0, dtype: object
# Username1     jocelynerickson
# Username2     jocelynerickson
# KloutScore                 42
# Name: 1673.0, dtype: object
# Username1     KevaZimmerman
# Username2     KevaZimmerman
# KloutScore               41
# Name: 1679.0, dtype: object
# Username1     lrcomedy101
# Username2     lrcomedy101
# KloutScore             19
# Name: 1683.0, dtype: object
# Username1     JRelnene
# Username2     JRelnene
# KloutScore          15
# Name: 1684.0, dtype: object

# %%
df1
# Out:
#                Username1        Username2 KloutScore
# NaN        cassiex0ellis      CanCanMarie         46
#  0.0              weswtf  FuckkUU_PayyMee         37
#  2.0        _AaronRenaud      Jushunter10         37
#  4.0      CayCay_McNitro   CayCay_McNitro         32
#  5.0     amontecalvo_515          Jsine35         32
#  6.0     victoriaarachel    LadyBugCharee         34
#  7.0       mikekowalski_            Tpavz         44
#  8.0      Kingg_Richard_  BallTil_IDie_LC         37
#  10.0            Cvman02          Cvman02         16
#  11.0           WeAreCha     Alex_Spinner         37
#  12.0    andnowimn0thing         m0ntr0se         50
#  13.0    ItsSydneyBitch9      ShyenneSayz         46
#  15.0       tupperbeware        chris_TPY         38
#  16.0          SRdipalot      SeanPhelan5         36
#  17.0      TopShelfBrews    TopShelfBrews         21
#  18.0      alexknowshtml       tonybgoode         61
#  19.0        becca_snell       erinsheaaa         36
#  20.0    SuperBaddrohadd  SuperBaddrohadd         42
#  21.0          _D1bound_      CjEdwardzzz         34
#  22.0     MzAzure_Roblez   MzAzure_Roblez         43
#  23.0          elilesser     kimberlykirn         20
#  24.0             JimEck           JimEck         30
#  25.0     TakemeasiamXo3        Malikk193         31
#  26.0        tylerwfitch         mbutterf         64
#  27.0        LivBieber11      LivBieber11         40
#  28.0        RayEllisIII    nicoleflankkk         39
#  29.0      nikkil0vezy00       wownicolee         44
#  30.0            DDougyy        Megglezzz         43
#  32.0         FreddyJ_23    SteffEsposito         36
#  34.0      VickNalentino       krysbabyxo         44
# ...                  ...              ...        ...
#  1594.0  Dont_JudgeChris  thisdorkjessica         40
#  1595.0      ToppingRose      ToppingRose         43
#  1597.0   Dr_ChrisMagboo        giiidavis         43
#  1598.0  CampingSurvival  CampingSurvival         71
#  1599.0           KiaNYC           KiaNYC         36
#  1600.0     Farley_OVOXO     julieziGZAGz         35
#  1601.0    MrAnthonyRaul    MrAnthonyRaul         41
#  1602.0      WrestleCade      WrestleCade         52
#  1604.0            exiva        joelfreak         40
#  1609.0        meagfahey       jfahey5856         24
#  1610.0    2Girls1Rickey   __AcapulcoGold         40
#  1614.0   TifoshinRogers   TifoshinRogers         24
#  1622.0       DaBoulRash       mo_abdul23         39
#  1630.0         YoGoWild         YoGoWild         25
#  1632.0    londrizzzzzle           yofuff         37
#  1634.0   emilygracepenn       alehouse76         29
#  1635.0             H4i5   MiSsChRiSsY011         40
#  1638.0      pa_davis101        WTFkrissy         47
#  1648.0         a_masone        jenmurph3         38
#  1649.0        NakaseArt        Kirbynite         29
#  1650.0      SteveNati35          bri_sco         48
#  1652.0       _weloveJay     OhThatsDerek         44
#  1653.0   NiceGuyTeele91   4ngelo5carfone         45
#  1654.0        moll_foxx          Cwalks3         37
#  1661.0       BobbyCz123          delbenz         45
#  1662.0    RbRLiveStudio    RbRLiveStudio         43
#  1673.0  jocelynerickson  jocelynerickson         42
#  1679.0    KevaZimmerman    KevaZimmerman         41
#  1683.0      lrcomedy101      lrcomedy101         19
#  1684.0         JRelnene         JRelnene         15
#
# [835 rows x 3 columns]

# %%
df1['KloutScore'].mean()
# Out:
# 37.9125748502994

# %%
df1.to_csv('geoKS.csv')

# %%
df = pd.read_csv('geoKS.csv')

# %%
df
# Out:
#      Unnamed: 0        Username1        Username2  KloutScore
# 0           NaN    cassiex0ellis      CanCanMarie          46
# 1           0.0           weswtf  FuckkUU_PayyMee          37
# 2           2.0     _AaronRenaud      Jushunter10          37
# 3           4.0   CayCay_McNitro   CayCay_McNitro          32
# 4           5.0  amontecalvo_515          Jsine35          32
# 5           6.0  victoriaarachel    LadyBugCharee          34
# 6           7.0    mikekowalski_            Tpavz          44
# 7           8.0   Kingg_Richard_  BallTil_IDie_LC          37
# 8          10.0          Cvman02          Cvman02          16
# 9          11.0         WeAreCha     Alex_Spinner          37
# 10         12.0  andnowimn0thing         m0ntr0se          50
# 11         13.0  ItsSydneyBitch9      ShyenneSayz          46
# 12         15.0     tupperbeware        chris_TPY          38
# 13         16.0        SRdipalot      SeanPhelan5          36
# 14         17.0    TopShelfBrews    TopShelfBrews          21
# 15         18.0    alexknowshtml       tonybgoode          61
# 16         19.0      becca_snell       erinsheaaa          36
# 17         20.0  SuperBaddrohadd  SuperBaddrohadd          42
# 18         21.0        _D1bound_      CjEdwardzzz          34
# 19         22.0   MzAzure_Roblez   MzAzure_Roblez          43
# 20         23.0        elilesser     kimberlykirn          20
# 21         24.0           JimEck           JimEck          30
# 22         25.0   TakemeasiamXo3        Malikk193          31
# 23         26.0      tylerwfitch         mbutterf          64
# 24         27.0      LivBieber11      LivBieber11          40
# 25         28.0      RayEllisIII    nicoleflankkk          39
# 26         29.0    nikkil0vezy00       wownicolee          44
# 27         30.0          DDougyy        Megglezzz          43
# 28         32.0       FreddyJ_23    SteffEsposito          36
# 29         34.0    VickNalentino       krysbabyxo          44
# ..          ...              ...              ...         ...
# 805      1594.0  Dont_JudgeChris  thisdorkjessica          40
# 806      1595.0      ToppingRose      ToppingRose          43
# 807      1597.0   Dr_ChrisMagboo        giiidavis          43
# 808      1598.0  CampingSurvival  CampingSurvival          71
# 809      1599.0           KiaNYC           KiaNYC          36
# 810      1600.0     Farley_OVOXO     julieziGZAGz          35
# 811      1601.0    MrAnthonyRaul    MrAnthonyRaul          41
# 812      1602.0      WrestleCade      WrestleCade          52
# 813      1604.0            exiva        joelfreak          40
# 814      1609.0        meagfahey       jfahey5856          24
# 815      1610.0    2Girls1Rickey   __AcapulcoGold          40
# 816      1614.0   TifoshinRogers   TifoshinRogers          24
# 817      1622.0       DaBoulRash       mo_abdul23          39
# 818      1630.0         YoGoWild         YoGoWild          25
# 819      1632.0    londrizzzzzle           yofuff          37
# 820      1634.0   emilygracepenn       alehouse76          29
# 821      1635.0             H4i5   MiSsChRiSsY011          40
# 822      1638.0      pa_davis101        WTFkrissy          47
# 823      1648.0         a_masone        jenmurph3          38
# 824      1649.0        NakaseArt        Kirbynite          29
# 825      1650.0      SteveNati35          bri_sco          48
# 826      1652.0       _weloveJay     OhThatsDerek          44
# 827      1653.0   NiceGuyTeele91   4ngelo5carfone          45
# 828      1654.0        moll_foxx          Cwalks3          37
# 829      1661.0       BobbyCz123          delbenz          45
# 830      1662.0    RbRLiveStudio    RbRLiveStudio          43
# 831      1673.0  jocelynerickson  jocelynerickson          42
# 832      1679.0    KevaZimmerman    KevaZimmerman          41
# 833      1683.0      lrcomedy101      lrcomedy101          19
# 834      1684.0         JRelnene         JRelnene          15
#
# [835 rows x 4 columns]
