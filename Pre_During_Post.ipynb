# %%
import pandas as pd

# %%
df=pd.read_csv('sandy_geo_sample200k.csv')

# %%
df[0:1]
# Out:
#    Author Name    Username                Tweet            Post Time - EST  \
# 0  ✩ *Beavis*✩  C_lorennxx  @Live_Strong_30 : /  2012-10-26 21:47:13-04:00
#
#    Klout Score  Retweet Count  Friends Count  Followers Count  \
# 0           50              0            365              387
#
#            Mentions
# 0  Live_Strong_30,

# %%
df_pre = df.loc[df["Post Time - EST"]<='2012-10-29 00:00:00']

# %%
df_pre[0:50]
# Out:
#               Author Name         Username  \
# 0             ✩ *Beavis*✩       C_lorennxx
# 2             john murphy   JACK_in_ur_box
# 4         Andrew D'Angelo   andrew_dangelo
# 6    shannon mclaughlin ✌        shann_mc3
# 9             Rodney Wren       RodneyWren
# 10           Tori Lussier      torilussier
# 11                 Ithaca   intercomithaca
# 13                A. LOWE   MuzikGenius101
# 14             loris yost     lorisqcwyost
# 15     eine südliche gent      AyoooooMont
# 18                    M A   primerAngolano
# 23           Filipe Palma         FilPalma
# 24        aℓaina brieℓℓe      abvanderziel
# 25         Loving my fab5    Martijfree304
# 32         The Red Knight     hoswell_Mufc
# 35              Ragan . ♥    RaganErricca_
# 36                  Metin          metink5
# 37        One Spicy Nacho  one_spicy_nacho
# 38          Lexie Curtis       curtis_lexi
# 40         ken obranovich         skinsken
# 44         ✨Moochie Mooh       __Moochieee
# ...

# %%
len(df_pre.index)
#len(df.index)
# Out:
# 87698

# %%
df_during = df.loc[(df["Post Time - EST"]>='2012-10-29 00:00:00') & (df["Post Time - EST"]<='2012-11-01 00:00:00') ]

# %%
df_during[0:5]
# Out:
#             Author Name   Username  \
# 8          rachel dietz    RDietz5
# 21            Madalena   LalaMada1
# 28  Kenzie Westmoreland  nirhalegi
# 42           Yulissaa ♥   yulieee3
# 46             jonathan     jonvox
#
#                                                 Tweet  \
# 8                             Wow bad move my friend.
# 21                  Good night my lovely tweeters! :)
# 28  #LoQueHubieraTuiteadoDeNiño eat much love.. @t...
# 42  I hate the fact that im going through the same...
# 46  @chrsphr it's hard to consider floods that bre...
#
#               Post Time - EST  Klout Score  Retweet Count  Friends Count  \
# 8   2012-10-31 13:48:07-04:00           41              0            139
# 21  2012-10-29 23:04:01-04:00           32              0             32
# 28  2012-10-30 01:49:22-04:00            0              0              0
# 42  2012-10-29 12:16:16-04:00           40              0            169
# ...

# %%
len(df_during.index)
# Out:
# 37336

# %%
df_post = df.loc[df["Post Time - EST"]>='2012-11-01 00:00:00' ]

# %%
df_post[0:10]
# Out:
#          Author Name         Username  \
# 1   Lebron's Barber™   iSlapThirsties
# 3             Ksenia          KseniaL
# 5     Chris LaLicata      clalicata17
# 7           Ginnette    caffeinehusky
# 12                GG         gabbbiee
# 16      laurencasale    laurencasale_
# 17         BabetteKD        BabetteKD
# 19        Sam Clarke        sammie_ce
# 20   Morgun Searight           orbiqa
# 22    shakia phoenix  shakiadnphoenix
#
#                                                 Tweet  \
# 1   I'm attentive , my opinion is monumental . I'm...
# 3   I totally saw them first.  @ DSW Designer Shoe...
# 5            Price is right is on at the gym... Score
# 7   I'm at rebalance (Cambridge, MA) http://t.co/t...
# 12   @nicki3diesel yeah man it really sucks its crazy
# 16  @JessicaNieberg1 hate to ruin this lovely twee...
# 17  Three ALTEC tree trimming trucks and one LIPA ...
# 19  "@GodPosts: Keep calm because.. http://t.co/Oo...
# ...

# %%
len(df_post.index)
# Out:
# 74966

# %%
df_pre.to_csv("Pre_Data_Geo.csv")

# %%
df_during.to_csv("During_Data_Geo.csv")

# %%
df1 = pd.read_csv("During_Data_Geo.csv")
len(df1.index)
# Out:
# 37347

# %%
df_post.to_csv("Post_Data_Geo.csv")

# %%
df_r = pd.read_csv("Pre_Data_Geo_1.csv")
# Out:
# /Users/dharanisethuram/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dkw=pd.read_csv('sandy_kw_sample200k.csv')

# %%
dkw[0:1]
# Out:
#   Author Name    Username                                              Tweet  \
# 0  BiasedGirl  BiasedGirl  RT @GovChristie: If conditions are not safe on...
#
#              Post Time - EST  Klout Score  Retweet Count  Friends Count  \
# 0  2012-10-29 20:29:37-04:00           63              0           6522
#
#    Followers Count       Mentions
# 0            10450  GovChristie,

# %%
dkw_pre = dkw.loc[dkw["Post Time - EST"]<='2012-10-29 00:00:00']

# %%
dkw_pre[0:3]
# Out:
#          Author Name         Username  \
# 2   Dan Rem-bare-all     ISEmanCometh
# 4    Wonderful World  WonderfulWorldz
# 14       Ivan Egorov      the1001news
#
#                                                 Tweet  \
# 2   Just now is everyone else feeling how I do abo...
# 4   VIDEO: Hurricane Sandy bears down on US: Hurri...
# 14  Hurricane Sandy promises be a strong, costly s...
#
#               Post Time - EST  Klout Score  Retweet Count  Friends Count  \
# 2   2012-10-26 07:08:23-04:00           40              0             66
# 4   2012-10-26 01:41:17-04:00           36              0            603
# 14  2012-10-27 13:46:30-04:00           40              0            494
#
#     Followers Count Mentions
# 2               196      NaN
# 4               485      NaN
# 14             1358      NaN

# %%
len(dkw_pre.index)
# Out:
# 41932

# %%
dkw_during = dkw.loc[(dkw["Post Time - EST"]>='2012-10-29 00:00:00') & (dkw["Post Time - EST"]<='2012-11-01 00:00:00') ]

# %%
dkw_during[0:2]
# Out:
#   Author Name     Username                                              Tweet  \
# 0  BiasedGirl   BiasedGirl  RT @GovChristie: If conditions are not safe on...
# 1    JM Boxer  TheFoxyBoxy  TCNJ Fall Break: We get two days off that we w...
#
#              Post Time - EST  Klout Score  Retweet Count  Friends Count  \
# 0  2012-10-29 20:29:37-04:00           63              0           6522
# 1  2012-10-29 17:45:27-04:00           31              0            118
#
#    Followers Count       Mentions
# 0            10450  GovChristie,
# 1              110            NaN

# %%
len(dkw_during.index)
# Out:
# 113396

# %%
dkw_post = dkw.loc[dkw["Post Time - EST"]>='2012-11-01 00:00:00' ]

# %%
dkw_post[0:2]
# Out:
#            Author Name         Username  \
# 7  DesertCharitiesNews  DesertCharities
# 9      Jonathan Schwab  Jonathan_Schwab
#
#                                                Tweet  \
# 7  Today Is Election Day - Don't Forget 2 Vote! W...
# 9  We're naming winter storms now? http://t.co/vh...
#
#              Post Time - EST  Klout Score  Retweet Count  Friends Count  \
# 7  2012-11-06 11:55:04-05:00           48              0           8214
# 9  2012-11-07 10:29:46-05:00           30              0            135
#
#    Followers Count Mentions
# 7             7558      NaN
# 9               67      NaN

# %%
len(dkw_post.index)
# Out:
# 44672

# %%
dkw_pre.to_csv("Pre_Data_Key.csv")

# %%
dkw_during.to_csv("During_Data_Key.csv")

# %%
dkw_post.to_csv("Post_Data_Key.csv")
